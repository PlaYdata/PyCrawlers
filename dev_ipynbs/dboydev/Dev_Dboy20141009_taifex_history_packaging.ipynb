# %%
import pandas as pd
from pandas.io.parsers import StringIO
import numpy as np
import requests
import csv
import re
import tempfile
import time
import os
import zipfile

# %%
def get_daily_history_taifex(start_date, end_date):
    assert isinstance(start_date, str) and isinstance(end_date, str), "date must be sting"
    pattern = re.compile("[0-9]{4}/[0-9]{2}/[0-9]{2}")
    match1 = pattern.match(start_date)
    match2 = pattern.match(end_date)
    assert not (match1 is None or match2 is None), "Wrong format of date. Date must be of yyyy/mm/dd format."
    
    time_tuple1 = time.strptime('{start_date} 0:0:0'.format(start_date = start_date), '%Y/%m/%d %H:%M:%S')
    time_in_sec1 = time.mktime(time_tuple1)
    time_tuple2= time.strptime('{end_date} 23:59:59'.format(end_date = end_date), '%Y/%m/%d %H:%M:%S')
    time_in_sec2 = time.mktime(time_tuple2)
    dur = time_in_sec2 - time_in_sec1 + 1
    assert dur <= 2592000.0, "Can not query data longer than 30 days."
    
    req_data = {"DATA_DATE":start_date,
                "DATA_DATE1":end_date,
                "COMMODITY_ID":"all",
                "commodity_id2t":""}
    res = requests.post("http://www.taifex.com.tw/eng/eng3/eng3_2dl.asp", data = req_data)
    res.encoding = "big5"
    csv_string = res.text.replace(u'\uff0b',u"+").replace(u'\uff0d',u"-").replace(u'\uff1a',u":").replace(u"\u2019", u"`")
    csvfile = StringIO(csv_string)
    rows = list(csv.reader(csvfile))
    columns_number_set = set(map(lambda xx: len(xx), rows))
    df_list = []
    for columns_number in columns_number_set:
        temp_rows = [one_row for one_row in rows if len(one_row) == columns_number]
        columns = map(lambda xx: " ".join(map(lambda yy: yy.capitalize(), re.split(" |_", xx))), temp_rows[0])
        temp_df = pd.DataFrame(temp_rows[1:], columns = columns)
        for colname in temp_df.columns:
            temp_df[colname] = temp_df[colname].map(lambda xx: xx.replace(u"-", "").replace(u",", ""))
        df_list.append(temp_df)
    return df_list

# %%
test = get_daily_history_taifex("2014/10/01", "2014/10/09")
test[0].head()
# Out:
#         Date Contract Contract Month(week)   Open   High    Low   Last Change  \
# 0  2014/10/1      XIF             201410    11237  11298  11190  11258     72
# 1  2014/10/1      XIF             201411    11212  11300  11186  11253     74
# 2  2014/10/1      XIF             201412
# 3  2014/10/1      XIF             201503
# 4  2014/10/1      XIF             201506
#
#        % Volume Settlement Price Open Interest Best Bid Best Ask  \
# 0  0.64%    543            11258           520    11243    11252
# 1  0.65%    153            11253            78    11241    11249
# 2                          11255            14
# 3                          11073             2
# 4                          11102             0
#
#   Historical High Historical Low
# 0           11831          11156
# 1           11525          11159
# 2
# 3
# 4

# %%
get_daily_history_taifex("2014/09/01", "2014/0930")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-4f4d0d87adb5> in <module>()
# ----> 1 get_daily_history_taifex("2014/09/01", "2014/0930")
#
# <ipython-input-2-eb830cfbc73c> in get_daily_history_taifex(start_date, end_date)
#       4     match1 = pattern.match(start_date)
#       5     match2 = pattern.match(end_date)
# ----> 6     assert not (match1 is None or match2 is None), "Wrong format of date. Date must be of yyyy/mm/dd format."
#       7
#       8     time_tuple1 = time.strptime('{start_date} 0:0:0'.format(start_date = start_date), '%Y/%m/%d %H:%M:%S')
#
# AssertionError: Wrong format of date. Date must be of yyyy/mm/dd format.

# %%
get_daily_history_taifex("2014/0901", "2014/0930")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-a6fe3f531859> in <module>()
# ----> 1 get_daily_history_taifex("2014/0901", "2014/0930")
#
# <ipython-input-2-eb830cfbc73c> in get_daily_history_taifex(start_date, end_date)
#       4     match1 = pattern.match(start_date)
#       5     match2 = pattern.match(end_date)
# ----> 6     assert not (match1 is None or match2 is None), "Wrong format of date. Date must be of yyyy/mm/dd format."
#       7
#       8     time_tuple1 = time.strptime('{start_date} 0:0:0'.format(start_date = start_date), '%Y/%m/%d %H:%M:%S')
#
# AssertionError: Wrong format of date. Date must be of yyyy/mm/dd format.

# %%
get_daily_history_taifex("2014/07/01", "2014/07/31")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-7e7ad48f3932> in <module>()
# ----> 1 get_daily_history_taifex("2014/07/01", "2014/07/31")
#
# <ipython-input-2-eb830cfbc73c> in get_daily_history_taifex(start_date, end_date)
#      11     time_in_sec2 = time.mktime(time_tuple2)
#      12     dur = time_in_sec2 - time_in_sec1 + 1
# ---> 13     assert dur <= 2592000.0, "Can not query data longer than 30 days."
#      14
#      15     req_data = {"DATA_DATE":start_date,
#
# AssertionError: Can not query data longer than 30 days.

# %%
test2 = get_daily_history_taifex("2013/07/01", "2013/07/30")

# %%
test2[0].head()
# Out:
#        Date Contract Contract Month(week)   Open   High    Low   Last Change  \
# 0  2013/7/1      XIF               201307  10544  10682  10544  10663     64
# 1  2013/7/1      XIF               201308  10442  10508  10431  10489     45
# 2  2013/7/1      XIF               201309
# 3  2013/7/1      XIF               201312
# 4  2013/7/1      XIF               201403
#
#        % Volume Settlement Price Open Interest Best Bid Best Ask  \
# 0  0.60%    449            10663           347    10661    10675
# 1  0.43%     36            10502            24    10495    10509
# 2                          10475             6
# 3                          10423             0
# 4                          10411             0
#
#   Historical High Historical Low
# 0           11211          10155
# 1           10508          10081
# 2
# 3
# 4

# %%
def get_annual_history_taifex(year, cache = False):
    assert isinstance(year, str), "year must be sting"
    pattern = re.compile("[0-9]{4}")
    match = pattern.match(year)
    assert not match is None, "Wrong format of year. Year must be of yyyy format."
    
    temp_path = tempfile.mkdtemp("_pycrawlers", "taifex_")
    url = "http://www.taifex.com.tw/eng/eng3/hisdata_fut/{year}_fut.zip".format(year = year)
    res = requests.get(url, stream = True)
    temp_zip = zipfile.ZipFile(StringIO(res.content))
    temp_zip.extractall(path = temp_path)
    df_list = []
    for filename in os.listdir(temp_path):
        file_path = os.path.join(temp_path, filename)
        with open(file_path, "r") as rf:
            temp_rows = rf.readlines()
        csvfile = StringIO("".join(temp_rows))
        rows = list(csv.reader(csvfile))
        temp_df = pd.DataFrame(rows[1:], columns = rows[0])
        temp_df.columns = map(lambda xx: " ".join(map(lambda yy: yy.capitalize(), re.split(" |_", xx))), temp_df.columns)
        for colname in temp_df.columns:
            temp_df[colname] = temp_df[colname].map(lambda xx: xx.replace(u"-", "").replace(u",", ""))
        df_list.append(temp_df)
    if not cache:
        os.system("rm -rf {path}".format(path = temp_path))
        return pd.concat(df_list)
    else:
        return pd.concat(df_list), temp_path

# %%
test = get_annual_history_taifex("2013")

# %%
test.tail()
# Out:
#               Date Contract Contract Month(week)  Open  High   Low  Last  \
# 159353  2013/12/31      GXF   201401/201402       0.03  0.03  0.03  0.03
# 159354  2013/12/31      DYF   201401/201403       0.02  0.02  0.02  0.02
# 159355  2013/12/31      DVF   201401/201402       1.59  1.59  1.88  1.88
# 159356  2013/12/31      DFF   201401/201402       0.06  0.06  0.07  0.07
# 159357  2013/12/31      CBF   201401/201402       0.03  0.03  0.03  0.03
#
#        Change % Volume Settlement Price Open Interest Best Bid Best Ask  \
# 159353               1                                     0.5     0.11
# 159354               2                                             0.02
# 159355               6                                       2     1.59
# 159356              15                                    0.08     0.06
# 159357               1                                    0.05     0.01
#
#        Historical High Historical Low
# 159353            0.03           0.03
# 159354            0.01           0.02
# 159355            0.21           1.88
# 159356            0.04           0.07
# 159357            0.02           0.03

# %%
get_annual_history_taifex("103")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-63-5a28e97832fb> in <module>()
# ----> 1 get_annual_history_taifex("103")
#
# <ipython-input-59-117ccde261bf> in get_annual_history_taifex(year, cache)
#       3     pattern = re.compile("[0-9]{4}")
#       4     match = pattern.match(year)
# ----> 5     assert not match is None, "Wrong format of year. Year must be of yyyy format."
#       6
#       7     temp_path = tempfile.mkdtemp("_pycrawlers", "taifex_")
#
# AssertionError: Wrong format of year. Year must be of yyyy format.

# %%
test2, temp_path = get_annual_history_taifex("2012", True)

# %%
temp_path
# Out:
# '/var/folders/5c/0p5zr2_n4xvbt2j6hkqczhph0000gn/T/taifex_gI_TrX_pycrawlers'
