# %%
import numpy as np
import requests
try:
    import ujson as json 
except:
    import json

class YoutubeChannelOpenData(object):
    def __init__(self, channel_id, datatype = "json"):
        assert datatype in ["xml", "json"], 'datatype must in ["xml", "json"]'        
        self.channel_id = channel_id
        self.datatype = datatype
        
    def get_data(self, datafeed_url, params = {}, key = None):
        if self.datatype == "json":
            params["alt"] = "json"
            r = requests.get(datafeed_url, params = params)
            if key == None:
                return json.loads(r.text)
            else:
                return json.loads(r.text)[key]
        else:
            if key == None:
                return requests.get(datafeed_url, params)
            else:
                return requests.get(datafeed_url, params)

    @property
    def base_url(self):
        return "https://gdata.youtube.com/feeds/users/{channel_id}/".format(channel_id=self.channel_id)
    
    @property
    def playlist_url(self):
        return "https://gdata.youtube.com/feeds/users/{channel_id}/playlists/".format(channel_id=self.channel_id)
    
    @property
    def uploads_url(self):
        return "https://gdata.youtube.com/feeds/users/{channel_id}/uploads/".format(channel_id=self.channel_id)

# %%
twusergroup = YoutubeChannelOpenData("TWuseRGroup")

data_feed = twusergroup.get_data(twusergroup.uploads_url, {}, "feed")
playlist_urls = [data_feed["link"][4]["href"], data_feed["link"][5]["href"]]

# %%
empty = False
while not empty:
    temp_data = twusergroup.get_data(playlist_urls[-1], {}, "feed")
    checking_list = []
    for item in temp_data["link"]:
        checking_list.append(item["rel"]) 
    if "next" in checking_list:
        ind = checking_list.index("next")
        playlist_urls.append(temp_data["link"][ind]["href"])
    else:
        empty = True

# %%
playlist_urls
# Out:
# [u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads?alt=json&start-index=1&max-results=25',
#  u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads?alt=json&start-index=26&max-results=25',
#  u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads?alt=json&start-index=51&max-results=25',
#  u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads?alt=json&start-index=76&max-results=25',
#  u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads?alt=json&start-index=101&max-results=25',
#  u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads?alt=json&start-index=126&max-results=25',
#  u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads?alt=json&start-index=151&max-results=25',
#  u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads?alt=json&start-index=176&max-results=25',
#  u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads?alt=json&start-index=201&max-results=25',
#  u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads?alt=json&start-index=226&max-results=25']

# %%
from pyquery import PyQuery

# %%
res = requests.get(playlist_urls[0])

# %%
js_obj = json.loads(res.text)

# %%
js_obj.keys()
# Out:
# [u'feed', u'version', u'encoding']

# %%
js_obj["feed"].keys()
# Out:
# [u'category',
#  u'openSearch$totalResults',
#  u'updated',
#  u'xmlns$gml',
#  u'openSearch$startIndex',
#  u'entry',
#  u'generator',
#  u'title',
#  u'author',
#  u'xmlns$yt',
#  u'xmlns',
#  u'xmlns$gd',
#  u'link',
#  u'xmlns$openSearch',
#  u'openSearch$itemsPerPage',
#  u'id',
#  u'logo',
#  u'xmlns$georss',
#  u'xmlns$media']

# %%
js_obj["feed"]["entry"]
# Out:
# [{u'author': [{u'name': {u'$t': u'TW use-R'},
#     u'uri': {u'$t': u'https://gdata.youtube.com/feeds/users/TWuseRGroup'}}],
#   u'category': [{u'scheme': u'http://schemas.google.com/g/2005#kind',
#     u'term': u'http://gdata.youtube.com/schemas/2007#video'},
#    {u'label': u'Science & Technology',
#     u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat',
#     u'term': u'Tech'}],
#   u'content': {u'$t': u'<div style="color: #000000;font-family: Arial, Helvetica, sans-serif;     font-size:12px; font-size: 12px; width: 555px;">\n<table cellspacing="0" cellpadding="0" border="0"><tbody><tr><td width="140" valign="top" rowspan="2"><div style="border: 1px solid #999999; margin: 0px 10px 5px 0px;"><a href="https://www.youtube.com/watch?v=i6ztCX5tQ_w&amp;feature=youtube_gdata"><img alt="" src="https://i.ytimg.com/vi/i6ztCX5tQ_w/0.jpg"></a></div></td>\n<td width="256" valign="top"><div style="font-size: 12px; font-weight: bold;"><a style="font-size: 15px; font-weight: bold;                  font-decoration: none;" href="https://www.youtube.com/watch?v=i6ztCX5tQ_w&amp;feature=youtube_gdata">20140804 R ETL part 16 by Aha&amp;&#22025;&#33907; (MLDM Monday)</a>\n<br></div>\n<div style="font-size: 12px; margin: 3px 0px;"><span>&#35611;&#38988;&#65306;TITLE\n&#35611;&#32773;&#65306;SPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]</span></div></td>\n<td style="font-size: 11px; line-height: 1.4em; padding-left: 20px;             padding-top: 1px;" width="146" valign="top"><div><span style="color: #666666; font-size: 11px;">From:</span>\n<a href="https://www.youtube.com/channel/UCBBwy_xvVsM5iLB5dJZDqog">TW use-R</a></div>\n<div><span style="color: #666666; font-size: 11px;">Views:</span>\n54</div>\n<div style="white-space: nowrap;text-align: left"><img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"></div>\n<div style="font-size: 11px;">0\n<span style="color: #666666; font-size: 11px;">ratings</span></div></td></tr>\n<tr><td><span style="color: #666666; font-size: 11px;">Time:</span>\n<span style="color: #000000; font-size: 11px; font-weight: bold;">12:42</span></td>\n<td style="font-size: 11px; padding-left: 20px;"><span style="color: #666666; font-size: 11px;">More in</span>\n<a href="https://www.youtube.com/videos?c=28">Science &amp; Technology</a></td></tr></tbody></table></div>',
#    u'type': u'html'},
#   u'gd$comments': {u'gd$feedLink': {u'countHint': 0,
#     u'href': u'https://gdata.youtube.com/feeds/videos/i6ztCX5tQ_w/comments',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#comments'}},
#   u'georss$where': {u'gml$Point': {u'gml$pos': {u'$t': u'25.0300998688 121.527618408'}}},
#   u'id': {u'$t': u'http://gdata.youtube.com/feeds/videos/i6ztCX5tQ_w'},
#   u'link': [{u'href': u'https://www.youtube.com/watch?v=i6ztCX5tQ_w&feature=youtube_gdata',
#     u'rel': u'alternate',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/videos/i6ztCX5tQ_w/related',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#video.related',
#     u'type': u'application/atom+xml'},
#    {u'href': u'https://m.youtube.com/details?v=i6ztCX5tQ_w',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#mobile',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads/i6ztCX5tQ_w',
#     u'rel': u'self',
#     u'type': u'application/atom+xml'}],
#   u'media$group': {u'media$category': [{u'$t': u'Tech',
#      u'label': u'Science & Technology',
#      u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat'}],
#    u'media$content': [{u'duration': 762,
#      u'expression': u'full',
#      u'isDefault': u'true',
#      u'medium': u'video',
#      u'type': u'application/x-shockwave-flash',
#      u'url': u'https://www.youtube.com/v/i6ztCX5tQ_w?version=3&f=user_uploads&app=youtube_gdata',
#      u'yt$format': 5},
#     {u'duration': 762,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r4---sn-o097zues.c.youtube.com/CigLENy73wIaHwn8Q21-Ce2sixMYDSANFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 1},
#     {u'duration': 762,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r4---sn-o097zues.c.youtube.com/CigLENy73wIaHwn8Q21-Ce2sixMYESARFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 6}],
#    u'media$description': {u'$t': u'\u8b1b\u984c\uff1aTITLE\n\u8b1b\u8005\uff1aSPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]',
#     u'type': u'plain'},
#    u'media$keywords': {},
#    u'media$player': [{u'url': u'https://www.youtube.com/watch?v=i6ztCX5tQ_w&feature=youtube_gdata_player'}],
#    u'media$thumbnail': [{u'height': 360,
#      u'time': u'00:06:21',
#      u'url': u'https://i.ytimg.com/vi/i6ztCX5tQ_w/0.jpg',
#      u'width': 480},
#     {u'height': 90,
#      u'time': u'00:03:10.500',
#      u'url': u'https://i.ytimg.com/vi/i6ztCX5tQ_w/1.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:06:21',
#      u'url': u'https://i.ytimg.com/vi/i6ztCX5tQ_w/2.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:09:31.500',
#      u'url': u'https://i.ytimg.com/vi/i6ztCX5tQ_w/3.jpg',
#      u'width': 120}],
#    u'media$title': {u'$t': u'20140804 R ETL part 16 by Aha&\u5609\u8473 (MLDM Monday)',
#     u'type': u'plain'},
#    u'yt$duration': {u'seconds': u'762'}},
#   u'published': {u'$t': u'2014-08-05T20:57:17.000Z'},
#   u'title': {u'$t': u'20140804 R ETL part 16 by Aha&\u5609\u8473 (MLDM Monday)',
#    u'type': u'text'},
#   u'updated': {u'$t': u'2014-08-05T20:57:17.000Z'},
#   u'yt$hd': {},
#   u'yt$statistics': {u'favoriteCount': u'0', u'viewCount': u'54'}},
#  {u'author': [{u'name': {u'$t': u'TW use-R'},
#     u'uri': {u'$t': u'https://gdata.youtube.com/feeds/users/TWuseRGroup'}}],
#   u'category': [{u'scheme': u'http://schemas.google.com/g/2005#kind',
#     u'term': u'http://gdata.youtube.com/schemas/2007#video'},
#    {u'label': u'Science & Technology',
#     u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat',
#     u'term': u'Tech'}],
#   u'content': {u'$t': u'<div style="color: #000000;font-family: Arial, Helvetica, sans-serif;     font-size:12px; font-size: 12px; width: 555px;">\n<table cellspacing="0" cellpadding="0" border="0"><tbody><tr><td width="140" valign="top" rowspan="2"><div style="border: 1px solid #999999; margin: 0px 10px 5px 0px;"><a href="https://www.youtube.com/watch?v=3vtTq7pf4ig&amp;feature=youtube_gdata"><img alt="" src="https://i.ytimg.com/vi/3vtTq7pf4ig/0.jpg"></a></div></td>\n<td width="256" valign="top"><div style="font-size: 12px; font-weight: bold;"><a style="font-size: 15px; font-weight: bold;                  font-decoration: none;" href="https://www.youtube.com/watch?v=3vtTq7pf4ig&amp;feature=youtube_gdata">20140721 R Basic part 5 by QMal (MLDM Monday)</a>\n<br></div>\n<div style="font-size: 12px; margin: 3px 0px;"><span>&#35611;&#38988;&#65306;TITLE\n&#35611;&#32773;&#65306;SPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]</span></div></td>\n<td style="font-size: 11px; line-height: 1.4em; padding-left: 20px;             padding-top: 1px;" width="146" valign="top"><div><span style="color: #666666; font-size: 11px;">From:</span>\n<a href="https://www.youtube.com/channel/UCBBwy_xvVsM5iLB5dJZDqog">TW use-R</a></div>\n<div><span style="color: #666666; font-size: 11px;">Views:</span>\n34</div>\n<div style="white-space: nowrap;text-align: left"><img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"></div>\n<div style="font-size: 11px;">0\n<span style="color: #666666; font-size: 11px;">ratings</span></div></td></tr>\n<tr><td><span style="color: #666666; font-size: 11px;">Time:</span>\n<span style="color: #000000; font-size: 11px; font-weight: bold;">12:40</span></td>\n<td style="font-size: 11px; padding-left: 20px;"><span style="color: #666666; font-size: 11px;">More in</span>\n<a href="https://www.youtube.com/videos?c=28">Science &amp; Technology</a></td></tr></tbody></table></div>',
#    u'type': u'html'},
#   u'gd$comments': {u'gd$feedLink': {u'countHint': 0,
#     u'href': u'https://gdata.youtube.com/feeds/videos/3vtTq7pf4ig/comments',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#comments'}},
#   u'georss$where': {u'gml$Point': {u'gml$pos': {u'$t': u'25.0300998688 121.527618408'}}},
#   u'id': {u'$t': u'http://gdata.youtube.com/feeds/videos/3vtTq7pf4ig'},
#   u'link': [{u'href': u'https://www.youtube.com/watch?v=3vtTq7pf4ig&feature=youtube_gdata',
#     u'rel': u'alternate',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/videos/3vtTq7pf4ig/related',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#video.related',
#     u'type': u'application/atom+xml'},
#    {u'href': u'https://m.youtube.com/details?v=3vtTq7pf4ig',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#mobile',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads/3vtTq7pf4ig',
#     u'rel': u'self',
#     u'type': u'application/atom+xml'}],
#   u'media$group': {u'media$category': [{u'$t': u'Tech',
#      u'label': u'Science & Technology',
#      u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat'}],
#    u'media$content': [{u'duration': 760,
#      u'expression': u'full',
#      u'isDefault': u'true',
#      u'medium': u'video',
#      u'type': u'application/x-shockwave-flash',
#      u'url': u'https://www.youtube.com/v/3vtTq7pf4ig?version=3&f=user_uploads&app=youtube_gdata',
#      u'yt$format': 5},
#     {u'duration': 760,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r1---sn-o097zue6.c.youtube.com/CigLENy73wIaHwko4l-6q1P73hMYDSANFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 1},
#     {u'duration': 760,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r1---sn-o097zue6.c.youtube.com/CigLENy73wIaHwko4l-6q1P73hMYESARFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 6}],
#    u'media$description': {u'$t': u'\u8b1b\u984c\uff1aTITLE\n\u8b1b\u8005\uff1aSPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]',
#     u'type': u'plain'},
#    u'media$keywords': {},
#    u'media$player': [{u'url': u'https://www.youtube.com/watch?v=3vtTq7pf4ig&feature=youtube_gdata_player'}],
#    u'media$thumbnail': [{u'height': 360,
#      u'time': u'00:06:20',
#      u'url': u'https://i.ytimg.com/vi/3vtTq7pf4ig/0.jpg',
#      u'width': 480},
#     {u'height': 90,
#      u'time': u'00:03:10',
#      u'url': u'https://i.ytimg.com/vi/3vtTq7pf4ig/1.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:06:20',
#      u'url': u'https://i.ytimg.com/vi/3vtTq7pf4ig/2.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:09:30',
#      u'url': u'https://i.ytimg.com/vi/3vtTq7pf4ig/3.jpg',
#      u'width': 120}],
#    u'media$title': {u'$t': u'20140721 R Basic part 5 by QMal (MLDM Monday)',
#     u'type': u'plain'},
#    u'yt$duration': {u'seconds': u'760'}},
#   u'published': {u'$t': u'2014-08-05T20:47:19.000Z'},
#   u'title': {u'$t': u'20140721 R Basic part 5 by QMal (MLDM Monday)',
#    u'type': u'text'},
#   u'updated': {u'$t': u'2014-08-05T20:47:19.000Z'},
#   u'yt$hd': {},
#   u'yt$statistics': {u'favoriteCount': u'0', u'viewCount': u'34'}},
#  {u'author': [{u'name': {u'$t': u'TW use-R'},
#     u'uri': {u'$t': u'https://gdata.youtube.com/feeds/users/TWuseRGroup'}}],
#   u'category': [{u'scheme': u'http://schemas.google.com/g/2005#kind',
#     u'term': u'http://gdata.youtube.com/schemas/2007#video'},
#    {u'label': u'Science & Technology',
#     u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat',
#     u'term': u'Tech'}],
#   u'content': {u'$t': u'<div style="color: #000000;font-family: Arial, Helvetica, sans-serif;     font-size:12px; font-size: 12px; width: 555px;">\n<table cellspacing="0" cellpadding="0" border="0"><tbody><tr><td width="140" valign="top" rowspan="2"><div style="border: 1px solid #999999; margin: 0px 10px 5px 0px;"><a href="https://www.youtube.com/watch?v=HdFcSqqveQI&amp;feature=youtube_gdata"><img alt="" src="https://i.ytimg.com/vi/HdFcSqqveQI/0.jpg"></a></div></td>\n<td width="256" valign="top"><div style="font-size: 12px; font-weight: bold;"><a style="font-size: 15px; font-weight: bold;                  font-decoration: none;" href="https://www.youtube.com/watch?v=HdFcSqqveQI&amp;feature=youtube_gdata">20140728 R ETL part 2 by Aha&amp;&#22025;&#33907; (MLDM Monday)</a>\n<br></div>\n<div style="font-size: 12px; margin: 3px 0px;"><span>&#35611;&#38988;&#65306;TITLE\n&#35611;&#32773;&#65306;SPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]</span></div></td>\n<td style="font-size: 11px; line-height: 1.4em; padding-left: 20px;             padding-top: 1px;" width="146" valign="top"><div><span style="color: #666666; font-size: 11px;">From:</span>\n<a href="https://www.youtube.com/channel/UCBBwy_xvVsM5iLB5dJZDqog">TW use-R</a></div>\n<div><span style="color: #666666; font-size: 11px;">Views:</span>\n77</div>\n<div style="white-space: nowrap;text-align: left"><img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"></div>\n<div style="font-size: 11px;">0\n<span style="color: #666666; font-size: 11px;">ratings</span></div></td></tr>\n<tr><td><span style="color: #666666; font-size: 11px;">Time:</span>\n<span style="color: #000000; font-size: 11px; font-weight: bold;">12:42</span></td>\n<td style="font-size: 11px; padding-left: 20px;"><span style="color: #666666; font-size: 11px;">More in</span>\n<a href="https://www.youtube.com/videos?c=28">Science &amp; Technology</a></td></tr></tbody></table></div>',
#    u'type': u'html'},
#   u'gd$comments': {u'gd$feedLink': {u'countHint': 0,
#     u'href': u'https://gdata.youtube.com/feeds/videos/HdFcSqqveQI/comments',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#comments'}},
#   u'georss$where': {u'gml$Point': {u'gml$pos': {u'$t': u'25.0300998688 121.527618408'}}},
#   u'id': {u'$t': u'http://gdata.youtube.com/feeds/videos/HdFcSqqveQI'},
#   u'link': [{u'href': u'https://www.youtube.com/watch?v=HdFcSqqveQI&feature=youtube_gdata',
#     u'rel': u'alternate',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/videos/HdFcSqqveQI/related',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#video.related',
#     u'type': u'application/atom+xml'},
#    {u'href': u'https://m.youtube.com/details?v=HdFcSqqveQI',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#mobile',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads/HdFcSqqveQI',
#     u'rel': u'self',
#     u'type': u'application/atom+xml'}],
#   u'media$group': {u'media$category': [{u'$t': u'Tech',
#      u'label': u'Science & Technology',
#      u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat'}],
#    u'media$content': [{u'duration': 762,
#      u'expression': u'full',
#      u'isDefault': u'true',
#      u'medium': u'video',
#      u'type': u'application/x-shockwave-flash',
#      u'url': u'https://www.youtube.com/v/HdFcSqqveQI?version=3&f=user_uploads&app=youtube_gdata',
#      u'yt$format': 5},
#     {u'duration': 762,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r6---sn-o097zuel.c.youtube.com/CigLENy73wIaHwkCea-qSlzRHRMYDSANFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 1},
#     {u'duration': 762,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r6---sn-o097zuel.c.youtube.com/CigLENy73wIaHwkCea-qSlzRHRMYESARFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 6}],
#    u'media$description': {u'$t': u'\u8b1b\u984c\uff1aTITLE\n\u8b1b\u8005\uff1aSPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]',
#     u'type': u'plain'},
#    u'media$keywords': {},
#    u'media$player': [{u'url': u'https://www.youtube.com/watch?v=HdFcSqqveQI&feature=youtube_gdata_player'}],
#    u'media$thumbnail': [{u'height': 360,
#      u'time': u'00:06:21',
#      u'url': u'https://i.ytimg.com/vi/HdFcSqqveQI/0.jpg',
#      u'width': 480},
#     {u'height': 90,
#      u'time': u'00:03:10.500',
#      u'url': u'https://i.ytimg.com/vi/HdFcSqqveQI/1.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:06:21',
#      u'url': u'https://i.ytimg.com/vi/HdFcSqqveQI/2.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:09:31.500',
#      u'url': u'https://i.ytimg.com/vi/HdFcSqqveQI/3.jpg',
#      u'width': 120}],
#    u'media$title': {u'$t': u'20140728 R ETL part 2 by Aha&\u5609\u8473 (MLDM Monday)',
#     u'type': u'plain'},
#    u'yt$duration': {u'seconds': u'762'}},
#   u'published': {u'$t': u'2014-08-05T20:45:14.000Z'},
#   u'title': {u'$t': u'20140728 R ETL part 2 by Aha&\u5609\u8473 (MLDM Monday)',
#    u'type': u'text'},
#   u'updated': {u'$t': u'2014-08-05T20:45:14.000Z'},
#   u'yt$hd': {},
#   u'yt$statistics': {u'favoriteCount': u'0', u'viewCount': u'77'}},
#  {u'author': [{u'name': {u'$t': u'TW use-R'},
#     u'uri': {u'$t': u'https://gdata.youtube.com/feeds/users/TWuseRGroup'}}],
#   u'category': [{u'scheme': u'http://schemas.google.com/g/2005#kind',
#     u'term': u'http://gdata.youtube.com/schemas/2007#video'},
#    {u'label': u'Science & Technology',
#     u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat',
#     u'term': u'Tech'}],
#   u'content': {u'$t': u'<div style="color: #000000;font-family: Arial, Helvetica, sans-serif;     font-size:12px; font-size: 12px; width: 555px;">\n<table cellspacing="0" cellpadding="0" border="0"><tbody><tr><td width="140" valign="top" rowspan="2"><div style="border: 1px solid #999999; margin: 0px 10px 5px 0px;"><a href="https://www.youtube.com/watch?v=yRCRK8HaXEM&amp;feature=youtube_gdata"><img alt="" src="https://i.ytimg.com/vi/yRCRK8HaXEM/0.jpg"></a></div></td>\n<td width="256" valign="top"><div style="font-size: 12px; font-weight: bold;"><a style="font-size: 15px; font-weight: bold;                  font-decoration: none;" href="https://www.youtube.com/watch?v=yRCRK8HaXEM&amp;feature=youtube_gdata">20140728 R ETL part 6 by Aha&amp;&#22025;&#33907; (MLDM Monday)</a>\n<br></div>\n<div style="font-size: 12px; margin: 3px 0px;"><span>&#35611;&#38988;&#65306;TITLE\n&#35611;&#32773;&#65306;SPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]</span></div></td>\n<td style="font-size: 11px; line-height: 1.4em; padding-left: 20px;             padding-top: 1px;" width="146" valign="top"><div><span style="color: #666666; font-size: 11px;">From:</span>\n<a href="https://www.youtube.com/channel/UCBBwy_xvVsM5iLB5dJZDqog">TW use-R</a></div>\n<div><span style="color: #666666; font-size: 11px;">Views:</span>\n33</div>\n<div style="white-space: nowrap;text-align: left"><img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"></div>\n<div style="font-size: 11px;">0\n<span style="color: #666666; font-size: 11px;">ratings</span></div></td></tr>\n<tr><td><span style="color: #666666; font-size: 11px;">Time:</span>\n<span style="color: #000000; font-size: 11px; font-weight: bold;">12:40</span></td>\n<td style="font-size: 11px; padding-left: 20px;"><span style="color: #666666; font-size: 11px;">More in</span>\n<a href="https://www.youtube.com/videos?c=28">Science &amp; Technology</a></td></tr></tbody></table></div>',
#    u'type': u'html'},
#   u'gd$comments': {u'gd$feedLink': {u'countHint': 0,
#     u'href': u'https://gdata.youtube.com/feeds/videos/yRCRK8HaXEM/comments',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#comments'}},
#   u'georss$where': {u'gml$Point': {u'gml$pos': {u'$t': u'25.0300998688 121.527618408'}}},
#   u'id': {u'$t': u'http://gdata.youtube.com/feeds/videos/yRCRK8HaXEM'},
#   u'link': [{u'href': u'https://www.youtube.com/watch?v=yRCRK8HaXEM&feature=youtube_gdata',
#     u'rel': u'alternate',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/videos/yRCRK8HaXEM/related',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#video.related',
#     u'type': u'application/atom+xml'},
#    {u'href': u'https://m.youtube.com/details?v=yRCRK8HaXEM',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#mobile',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads/yRCRK8HaXEM',
#     u'rel': u'self',
#     u'type': u'application/atom+xml'}],
#   u'media$group': {u'media$category': [{u'$t': u'Tech',
#      u'label': u'Science & Technology',
#      u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat'}],
#    u'media$content': [{u'duration': 760,
#      u'expression': u'full',
#      u'isDefault': u'true',
#      u'medium': u'video',
#      u'type': u'application/x-shockwave-flash',
#      u'url': u'https://www.youtube.com/v/yRCRK8HaXEM?version=3&f=user_uploads&app=youtube_gdata',
#      u'yt$format': 5},
#     {u'duration': 760,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r5---sn-o097zuee.c.youtube.com/CigLENy73wIaHwlDXNrBK5EQyRMYDSANFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 1},
#     {u'duration': 760,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r5---sn-o097zuee.c.youtube.com/CigLENy73wIaHwlDXNrBK5EQyRMYESARFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 6}],
#    u'media$description': {u'$t': u'\u8b1b\u984c\uff1aTITLE\n\u8b1b\u8005\uff1aSPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]',
#     u'type': u'plain'},
#    u'media$keywords': {},
#    u'media$player': [{u'url': u'https://www.youtube.com/watch?v=yRCRK8HaXEM&feature=youtube_gdata_player'}],
#    u'media$thumbnail': [{u'height': 360,
#      u'time': u'00:06:20',
#      u'url': u'https://i.ytimg.com/vi/yRCRK8HaXEM/0.jpg',
#      u'width': 480},
#     {u'height': 90,
#      u'time': u'00:03:10',
#      u'url': u'https://i.ytimg.com/vi/yRCRK8HaXEM/1.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:06:20',
#      u'url': u'https://i.ytimg.com/vi/yRCRK8HaXEM/2.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:09:30',
#      u'url': u'https://i.ytimg.com/vi/yRCRK8HaXEM/3.jpg',
#      u'width': 120}],
#    u'media$title': {u'$t': u'20140728 R ETL part 6 by Aha&\u5609\u8473 (MLDM Monday)',
#     u'type': u'plain'},
#    u'yt$duration': {u'seconds': u'760'}},
#   u'published': {u'$t': u'2014-08-05T19:24:18.000Z'},
#   u'title': {u'$t': u'20140728 R ETL part 6 by Aha&\u5609\u8473 (MLDM Monday)',
#    u'type': u'text'},
#   u'updated': {u'$t': u'2014-08-05T19:24:18.000Z'},
#   u'yt$hd': {},
#   u'yt$statistics': {u'favoriteCount': u'0', u'viewCount': u'33'}},
#  {u'author': [{u'name': {u'$t': u'TW use-R'},
#     u'uri': {u'$t': u'https://gdata.youtube.com/feeds/users/TWuseRGroup'}}],
#   u'category': [{u'scheme': u'http://schemas.google.com/g/2005#kind',
#     u'term': u'http://gdata.youtube.com/schemas/2007#video'},
#    {u'label': u'Science & Technology',
#     u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat',
#     u'term': u'Tech'}],
#   u'content': {u'$t': u'<div style="color: #000000;font-family: Arial, Helvetica, sans-serif;     font-size:12px; font-size: 12px; width: 555px;">\n<table cellspacing="0" cellpadding="0" border="0"><tbody><tr><td width="140" valign="top" rowspan="2"><div style="border: 1px solid #999999; margin: 0px 10px 5px 0px;"><a href="https://www.youtube.com/watch?v=e91F30fzsYI&amp;feature=youtube_gdata"><img alt="" src="https://i.ytimg.com/vi/e91F30fzsYI/0.jpg"></a></div></td>\n<td width="256" valign="top"><div style="font-size: 12px; font-weight: bold;"><a style="font-size: 15px; font-weight: bold;                  font-decoration: none;" href="https://www.youtube.com/watch?v=e91F30fzsYI&amp;feature=youtube_gdata">20140804 R ETL part 17 by Aha&amp;&#22025;&#33907; (MLDM Monday)</a>\n<br></div>\n<div style="font-size: 12px; margin: 3px 0px;"><span>&#35611;&#38988;&#65306;TITLE\n&#35611;&#32773;&#65306;SPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]</span></div></td>\n<td style="font-size: 11px; line-height: 1.4em; padding-left: 20px;             padding-top: 1px;" width="146" valign="top"><div><span style="color: #666666; font-size: 11px;">From:</span>\n<a href="https://www.youtube.com/channel/UCBBwy_xvVsM5iLB5dJZDqog">TW use-R</a></div>\n<div><span style="color: #666666; font-size: 11px;">Views:</span>\n34</div>\n<div style="white-space: nowrap;text-align: left"><img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"></div>\n<div style="font-size: 11px;">0\n<span style="color: #666666; font-size: 11px;">ratings</span></div></td></tr>\n<tr><td><span style="color: #666666; font-size: 11px;">Time:</span>\n<span style="color: #000000; font-size: 11px; font-weight: bold;">12:15</span></td>\n<td style="font-size: 11px; padding-left: 20px;"><span style="color: #666666; font-size: 11px;">More in</span>\n<a href="https://www.youtube.com/videos?c=28">Science &amp; Technology</a></td></tr></tbody></table></div>',
#    u'type': u'html'},
#   u'gd$comments': {u'gd$feedLink': {u'countHint': 0,
#     u'href': u'https://gdata.youtube.com/feeds/videos/e91F30fzsYI/comments',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#comments'}},
#   u'georss$where': {u'gml$Point': {u'gml$pos': {u'$t': u'25.0300998688 121.527618408'}}},
#   u'id': {u'$t': u'http://gdata.youtube.com/feeds/videos/e91F30fzsYI'},
#   u'link': [{u'href': u'https://www.youtube.com/watch?v=e91F30fzsYI&feature=youtube_gdata',
#     u'rel': u'alternate',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/videos/e91F30fzsYI/related',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#video.related',
#     u'type': u'application/atom+xml'},
#    {u'href': u'https://m.youtube.com/details?v=e91F30fzsYI',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#mobile',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads/e91F30fzsYI',
#     u'rel': u'self',
#     u'type': u'application/atom+xml'}],
#   u'media$group': {u'media$category': [{u'$t': u'Tech',
#      u'label': u'Science & Technology',
#      u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat'}],
#    u'media$content': [{u'duration': 735,
#      u'expression': u'full',
#      u'isDefault': u'true',
#      u'medium': u'video',
#      u'type': u'application/x-shockwave-flash',
#      u'url': u'https://www.youtube.com/v/e91F30fzsYI?version=3&f=user_uploads&app=youtube_gdata',
#      u'yt$format': 5},
#     {u'duration': 735,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r1---sn-o097zuel.c.youtube.com/CigLENy73wIaHwmCsfNH30XdexMYDSANFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 1},
#     {u'duration': 735,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r1---sn-o097zuel.c.youtube.com/CigLENy73wIaHwmCsfNH30XdexMYESARFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 6}],
#    u'media$description': {u'$t': u'\u8b1b\u984c\uff1aTITLE\n\u8b1b\u8005\uff1aSPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]',
#     u'type': u'plain'},
#    u'media$keywords': {},
#    u'media$player': [{u'url': u'https://www.youtube.com/watch?v=e91F30fzsYI&feature=youtube_gdata_player'}],
#    u'media$thumbnail': [{u'height': 360,
#      u'time': u'00:06:07.500',
#      u'url': u'https://i.ytimg.com/vi/e91F30fzsYI/0.jpg',
#      u'width': 480},
#     {u'height': 90,
#      u'time': u'00:03:03.750',
#      u'url': u'https://i.ytimg.com/vi/e91F30fzsYI/1.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:06:07.500',
#      u'url': u'https://i.ytimg.com/vi/e91F30fzsYI/2.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:09:11.250',
#      u'url': u'https://i.ytimg.com/vi/e91F30fzsYI/3.jpg',
#      u'width': 120}],
#    u'media$title': {u'$t': u'20140804 R ETL part 17 by Aha&\u5609\u8473 (MLDM Monday)',
#     u'type': u'plain'},
#    u'yt$duration': {u'seconds': u'735'}},
#   u'published': {u'$t': u'2014-08-05T19:16:21.000Z'},
#   u'title': {u'$t': u'20140804 R ETL part 17 by Aha&\u5609\u8473 (MLDM Monday)',
#    u'type': u'text'},
#   u'updated': {u'$t': u'2014-08-05T19:16:21.000Z'},
#   u'yt$hd': {},
#   u'yt$statistics': {u'favoriteCount': u'0', u'viewCount': u'34'}},
#  {u'author': [{u'name': {u'$t': u'TW use-R'},
#     u'uri': {u'$t': u'https://gdata.youtube.com/feeds/users/TWuseRGroup'}}],
#   u'category': [{u'scheme': u'http://schemas.google.com/g/2005#kind',
#     u'term': u'http://gdata.youtube.com/schemas/2007#video'},
#    {u'label': u'Science & Technology',
#     u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat',
#     u'term': u'Tech'}],
#   u'content': {u'$t': u'<div style="color: #000000;font-family: Arial, Helvetica, sans-serif;     font-size:12px; font-size: 12px; width: 555px;">\n<table cellspacing="0" cellpadding="0" border="0"><tbody><tr><td width="140" valign="top" rowspan="2"><div style="border: 1px solid #999999; margin: 0px 10px 5px 0px;"><a href="https://www.youtube.com/watch?v=adjucZLJhAY&amp;feature=youtube_gdata"><img alt="" src="https://i.ytimg.com/vi/adjucZLJhAY/0.jpg"></a></div></td>\n<td width="256" valign="top"><div style="font-size: 12px; font-weight: bold;"><a style="font-size: 15px; font-weight: bold;                  font-decoration: none;" href="https://www.youtube.com/watch?v=adjucZLJhAY&amp;feature=youtube_gdata">20140804 R ETL part 15 by Aha&amp;&#22025;&#33907; (MLDM Monday)</a>\n<br></div>\n<div style="font-size: 12px; margin: 3px 0px;"><span>&#35611;&#38988;&#65306;TITLE\n&#35611;&#32773;&#65306;SPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]</span></div></td>\n<td style="font-size: 11px; line-height: 1.4em; padding-left: 20px;             padding-top: 1px;" width="146" valign="top"><div><span style="color: #666666; font-size: 11px;">From:</span>\n<a href="https://www.youtube.com/channel/UCBBwy_xvVsM5iLB5dJZDqog">TW use-R</a></div>\n<div><span style="color: #666666; font-size: 11px;">Views:</span>\n38</div>\n<div style="white-space: nowrap;text-align: left"><img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"></div>\n<div style="font-size: 11px;">0\n<span style="color: #666666; font-size: 11px;">ratings</span></div></td></tr>\n<tr><td><span style="color: #666666; font-size: 11px;">Time:</span>\n<span style="color: #000000; font-size: 11px; font-weight: bold;">12:41</span></td>\n<td style="font-size: 11px; padding-left: 20px;"><span style="color: #666666; font-size: 11px;">More in</span>\n<a href="https://www.youtube.com/videos?c=28">Science &amp; Technology</a></td></tr></tbody></table></div>',
#    u'type': u'html'},
#   u'gd$comments': {u'gd$feedLink': {u'countHint': 0,
#     u'href': u'https://gdata.youtube.com/feeds/videos/adjucZLJhAY/comments',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#comments'}},
#   u'georss$where': {u'gml$Point': {u'gml$pos': {u'$t': u'25.0300998688 121.527618408'}}},
#   u'id': {u'$t': u'http://gdata.youtube.com/feeds/videos/adjucZLJhAY'},
#   u'link': [{u'href': u'https://www.youtube.com/watch?v=adjucZLJhAY&feature=youtube_gdata',
#     u'rel': u'alternate',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/videos/adjucZLJhAY/related',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#video.related',
#     u'type': u'application/atom+xml'},
#    {u'href': u'https://m.youtube.com/details?v=adjucZLJhAY',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#mobile',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads/adjucZLJhAY',
#     u'rel': u'self',
#     u'type': u'application/atom+xml'}],
#   u'media$group': {u'media$category': [{u'$t': u'Tech',
#      u'label': u'Science & Technology',
#      u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat'}],
#    u'media$content': [{u'duration': 761,
#      u'expression': u'full',
#      u'isDefault': u'true',
#      u'medium': u'video',
#      u'type': u'application/x-shockwave-flash',
#      u'url': u'https://www.youtube.com/v/adjucZLJhAY?version=3&f=user_uploads&app=youtube_gdata',
#      u'yt$format': 5},
#     {u'duration': 761,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r7---sn-o097zue6.c.youtube.com/CigLENy73wIaHwkGhMmSce7YaRMYDSANFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 1},
#     {u'duration': 761,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r7---sn-o097zue6.c.youtube.com/CigLENy73wIaHwkGhMmSce7YaRMYESARFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 6}],
#    u'media$description': {u'$t': u'\u8b1b\u984c\uff1aTITLE\n\u8b1b\u8005\uff1aSPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]',
#     u'type': u'plain'},
#    u'media$keywords': {},
#    u'media$player': [{u'url': u'https://www.youtube.com/watch?v=adjucZLJhAY&feature=youtube_gdata_player'}],
#    u'media$thumbnail': [{u'height': 360,
#      u'time': u'00:06:20.500',
#      u'url': u'https://i.ytimg.com/vi/adjucZLJhAY/0.jpg',
#      u'width': 480},
#     {u'height': 90,
#      u'time': u'00:03:10.250',
#      u'url': u'https://i.ytimg.com/vi/adjucZLJhAY/1.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:06:20.500',
#      u'url': u'https://i.ytimg.com/vi/adjucZLJhAY/2.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:09:30.750',
#      u'url': u'https://i.ytimg.com/vi/adjucZLJhAY/3.jpg',
#      u'width': 120}],
#    u'media$title': {u'$t': u'20140804 R ETL part 15 by Aha&\u5609\u8473 (MLDM Monday)',
#     u'type': u'plain'},
#    u'yt$duration': {u'seconds': u'761'}},
#   u'published': {u'$t': u'2014-08-05T19:00:44.000Z'},
#   u'title': {u'$t': u'20140804 R ETL part 15 by Aha&\u5609\u8473 (MLDM Monday)',
#    u'type': u'text'},
#   u'updated': {u'$t': u'2014-08-05T19:00:44.000Z'},
#   u'yt$hd': {},
#   u'yt$statistics': {u'favoriteCount': u'0', u'viewCount': u'38'}},
#  {u'author': [{u'name': {u'$t': u'TW use-R'},
#     u'uri': {u'$t': u'https://gdata.youtube.com/feeds/users/TWuseRGroup'}}],
#   u'category': [{u'scheme': u'http://schemas.google.com/g/2005#kind',
#     u'term': u'http://gdata.youtube.com/schemas/2007#video'},
#    {u'label': u'Science & Technology',
#     u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat',
#     u'term': u'Tech'}],
#   u'content': {u'$t': u'<div style="color: #000000;font-family: Arial, Helvetica, sans-serif;     font-size:12px; font-size: 12px; width: 555px;">\n<table cellspacing="0" cellpadding="0" border="0"><tbody><tr><td width="140" valign="top" rowspan="2"><div style="border: 1px solid #999999; margin: 0px 10px 5px 0px;"><a href="https://www.youtube.com/watch?v=FpoXlxxtkTA&amp;feature=youtube_gdata"><img alt="" src="https://i.ytimg.com/vi/FpoXlxxtkTA/0.jpg"></a></div></td>\n<td width="256" valign="top"><div style="font-size: 12px; font-weight: bold;"><a style="font-size: 15px; font-weight: bold;                  font-decoration: none;" href="https://www.youtube.com/watch?v=FpoXlxxtkTA&amp;feature=youtube_gdata">20140804 R ETL part 13 by Aha&amp;&#22025;&#33907; (MLDM Monday)</a>\n<br></div>\n<div style="font-size: 12px; margin: 3px 0px;"><span>&#35611;&#38988;&#65306;TITLE\n&#35611;&#32773;&#65306;SPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]</span></div></td>\n<td style="font-size: 11px; line-height: 1.4em; padding-left: 20px;             padding-top: 1px;" width="146" valign="top"><div><span style="color: #666666; font-size: 11px;">From:</span>\n<a href="https://www.youtube.com/channel/UCBBwy_xvVsM5iLB5dJZDqog">TW use-R</a></div>\n<div><span style="color: #666666; font-size: 11px;">Views:</span>\n25</div>\n<div style="white-space: nowrap;text-align: left"><img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"></div>\n<div style="font-size: 11px;">0\n<span style="color: #666666; font-size: 11px;">ratings</span></div></td></tr>\n<tr><td><span style="color: #666666; font-size: 11px;">Time:</span>\n<span style="color: #000000; font-size: 11px; font-weight: bold;">12:42</span></td>\n<td style="font-size: 11px; padding-left: 20px;"><span style="color: #666666; font-size: 11px;">More in</span>\n<a href="https://www.youtube.com/videos?c=28">Science &amp; Technology</a></td></tr></tbody></table></div>',
#    u'type': u'html'},
#   u'gd$comments': {u'gd$feedLink': {u'countHint': 0,
#     u'href': u'https://gdata.youtube.com/feeds/videos/FpoXlxxtkTA/comments',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#comments'}},
#   u'georss$where': {u'gml$Point': {u'gml$pos': {u'$t': u'25.0300998688 121.527618408'}}},
#   u'id': {u'$t': u'http://gdata.youtube.com/feeds/videos/FpoXlxxtkTA'},
#   u'link': [{u'href': u'https://www.youtube.com/watch?v=FpoXlxxtkTA&feature=youtube_gdata',
#     u'rel': u'alternate',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/videos/FpoXlxxtkTA/related',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#video.related',
#     u'type': u'application/atom+xml'},
#    {u'href': u'https://m.youtube.com/details?v=FpoXlxxtkTA',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#mobile',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads/FpoXlxxtkTA',
#     u'rel': u'self',
#     u'type': u'application/atom+xml'}],
#   u'media$group': {u'media$category': [{u'$t': u'Tech',
#      u'label': u'Science & Technology',
#      u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat'}],
#    u'media$content': [{u'duration': 762,
#      u'expression': u'full',
#      u'isDefault': u'true',
#      u'medium': u'video',
#      u'type': u'application/x-shockwave-flash',
#      u'url': u'https://www.youtube.com/v/FpoXlxxtkTA?version=3&f=user_uploads&app=youtube_gdata',
#      u'yt$format': 5},
#     {u'duration': 762,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r8---sn-o097zuer.c.youtube.com/CigLENy73wIaHwkwkW0clxeaFhMYDSANFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 1},
#     {u'duration': 762,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r8---sn-o097zuer.c.youtube.com/CigLENy73wIaHwkwkW0clxeaFhMYESARFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 6}],
#    u'media$description': {u'$t': u'\u8b1b\u984c\uff1aTITLE\n\u8b1b\u8005\uff1aSPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]',
#     u'type': u'plain'},
#    u'media$keywords': {},
#    u'media$player': [{u'url': u'https://www.youtube.com/watch?v=FpoXlxxtkTA&feature=youtube_gdata_player'}],
#    u'media$thumbnail': [{u'height': 360,
#      u'time': u'00:06:21',
#      u'url': u'https://i.ytimg.com/vi/FpoXlxxtkTA/0.jpg',
#      u'width': 480},
#     {u'height': 90,
#      u'time': u'00:03:10.500',
#      u'url': u'https://i.ytimg.com/vi/FpoXlxxtkTA/1.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:06:21',
#      u'url': u'https://i.ytimg.com/vi/FpoXlxxtkTA/2.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:09:31.500',
#      u'url': u'https://i.ytimg.com/vi/FpoXlxxtkTA/3.jpg',
#      u'width': 120}],
#    u'media$title': {u'$t': u'20140804 R ETL part 13 by Aha&\u5609\u8473 (MLDM Monday)',
#     u'type': u'plain'},
#    u'yt$duration': {u'seconds': u'762'}},
#   u'published': {u'$t': u'2014-08-05T18:59:27.000Z'},
#   u'title': {u'$t': u'20140804 R ETL part 13 by Aha&\u5609\u8473 (MLDM Monday)',
#    u'type': u'text'},
#   u'updated': {u'$t': u'2014-08-05T18:59:27.000Z'},
#   u'yt$hd': {},
#   u'yt$statistics': {u'favoriteCount': u'0', u'viewCount': u'25'}},
#  {u'author': [{u'name': {u'$t': u'TW use-R'},
#     u'uri': {u'$t': u'https://gdata.youtube.com/feeds/users/TWuseRGroup'}}],
#   u'category': [{u'scheme': u'http://schemas.google.com/g/2005#kind',
#     u'term': u'http://gdata.youtube.com/schemas/2007#video'},
#    {u'label': u'Science & Technology',
#     u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat',
#     u'term': u'Tech'}],
# ...
#    {u'href': u'https://gdata.youtube.com/feeds/videos/QRiEeP056_M/related',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#video.related',
#     u'type': u'application/atom+xml'},
#    {u'href': u'https://m.youtube.com/details?v=QRiEeP056_M',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#mobile',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads/QRiEeP056_M',
#     u'rel': u'self',
#     u'type': u'application/atom+xml'}],
#   u'media$group': {u'media$category': [{u'$t': u'Tech',
#      u'label': u'Science & Technology',
#      u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat'}],
#    u'media$content': [{u'duration': 762,
#      u'expression': u'full',
#      u'isDefault': u'true',
#      u'medium': u'video',
#      u'type': u'application/x-shockwave-flash',
#      u'url': u'https://www.youtube.com/v/QRiEeP056_M?version=3&f=user_uploads&app=youtube_gdata',
#      u'yt$format': 5},
#     {u'duration': 762,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r2---sn-o097zue6.c.youtube.com/CigLENy73wIaHwnz6zn9eIQYQRMYDSANFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 1},
#     {u'duration': 762,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r2---sn-o097zue6.c.youtube.com/CigLENy73wIaHwnz6zn9eIQYQRMYESARFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 6}],
#    u'media$description': {u'$t': u'\u8b1b\u984c\uff1aTITLE\n\u8b1b\u8005\uff1aSPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]',
#     u'type': u'plain'},
#    u'media$keywords': {},
#    u'media$player': [{u'url': u'https://www.youtube.com/watch?v=QRiEeP056_M&feature=youtube_gdata_player'}],
#    u'media$thumbnail': [{u'height': 360,
#      u'time': u'00:06:21',
#      u'url': u'https://i.ytimg.com/vi/QRiEeP056_M/0.jpg',
#      u'width': 480},
#     {u'height': 90,
#      u'time': u'00:03:10.500',
#      u'url': u'https://i.ytimg.com/vi/QRiEeP056_M/1.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:06:21',
#      u'url': u'https://i.ytimg.com/vi/QRiEeP056_M/2.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:09:31.500',
#      u'url': u'https://i.ytimg.com/vi/QRiEeP056_M/3.jpg',
#      u'width': 120}],
#    u'media$title': {u'$t': u'20140721 R Basic part 2 by QMal (MLDM Monday)',
#     u'type': u'plain'},
#    u'yt$duration': {u'seconds': u'762'}},
#   u'published': {u'$t': u'2014-08-05T17:06:34.000Z'},
#   u'title': {u'$t': u'20140721 R Basic part 2 by QMal (MLDM Monday)',
#    u'type': u'text'},
#   u'updated': {u'$t': u'2014-08-05T17:06:34.000Z'},
#   u'yt$hd': {},
#   u'yt$statistics': {u'favoriteCount': u'0', u'viewCount': u'73'}},
#  {u'author': [{u'name': {u'$t': u'TW use-R'},
#     u'uri': {u'$t': u'https://gdata.youtube.com/feeds/users/TWuseRGroup'}}],
#   u'category': [{u'scheme': u'http://schemas.google.com/g/2005#kind',
#     u'term': u'http://gdata.youtube.com/schemas/2007#video'},
#    {u'label': u'Science & Technology',
#     u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat',
#     u'term': u'Tech'}],
#   u'content': {u'$t': u'<div style="color: #000000;font-family: Arial, Helvetica, sans-serif;     font-size:12px; font-size: 12px; width: 555px;">\n<table cellspacing="0" cellpadding="0" border="0"><tbody><tr><td width="140" valign="top" rowspan="2"><div style="border: 1px solid #999999; margin: 0px 10px 5px 0px;"><a href="https://www.youtube.com/watch?v=knUMjsGaL4s&amp;feature=youtube_gdata"><img alt="" src="https://i.ytimg.com/vi/knUMjsGaL4s/0.jpg"></a></div></td>\n<td width="256" valign="top"><div style="font-size: 12px; font-weight: bold;"><a style="font-size: 15px; font-weight: bold;                  font-decoration: none;" href="https://www.youtube.com/watch?v=knUMjsGaL4s&amp;feature=youtube_gdata">20140721 R Basic part 9 by QMal (MLDM Monday)</a>\n<br></div>\n<div style="font-size: 12px; margin: 3px 0px;"><span>&#35611;&#38988;&#65306;TITLE\n&#35611;&#32773;&#65306;SPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]</span></div></td>\n<td style="font-size: 11px; line-height: 1.4em; padding-left: 20px;             padding-top: 1px;" width="146" valign="top"><div><span style="color: #666666; font-size: 11px;">From:</span>\n<a href="https://www.youtube.com/channel/UCBBwy_xvVsM5iLB5dJZDqog">TW use-R</a></div>\n<div><span style="color: #666666; font-size: 11px;">Views:</span>\n17</div>\n<div style="white-space: nowrap;text-align: left"><img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"></div>\n<div style="font-size: 11px;">0\n<span style="color: #666666; font-size: 11px;">ratings</span></div></td></tr>\n<tr><td><span style="color: #666666; font-size: 11px;">Time:</span>\n<span style="color: #000000; font-size: 11px; font-weight: bold;">02:10</span></td>\n<td style="font-size: 11px; padding-left: 20px;"><span style="color: #666666; font-size: 11px;">More in</span>\n<a href="https://www.youtube.com/videos?c=28">Science &amp; Technology</a></td></tr></tbody></table></div>',
#    u'type': u'html'},
#   u'gd$comments': {u'gd$feedLink': {u'countHint': 0,
#     u'href': u'https://gdata.youtube.com/feeds/videos/knUMjsGaL4s/comments',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#comments'}},
#   u'georss$where': {u'gml$Point': {u'gml$pos': {u'$t': u'25.0300998688 121.527618408'}}},
#   u'id': {u'$t': u'http://gdata.youtube.com/feeds/videos/knUMjsGaL4s'},
#   u'link': [{u'href': u'https://www.youtube.com/watch?v=knUMjsGaL4s&feature=youtube_gdata',
#     u'rel': u'alternate',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/videos/knUMjsGaL4s/related',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#video.related',
#     u'type': u'application/atom+xml'},
#    {u'href': u'https://m.youtube.com/details?v=knUMjsGaL4s',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#mobile',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads/knUMjsGaL4s',
#     u'rel': u'self',
#     u'type': u'application/atom+xml'}],
#   u'media$group': {u'media$category': [{u'$t': u'Tech',
#      u'label': u'Science & Technology',
#      u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat'}],
#    u'media$content': [{u'duration': 130,
#      u'expression': u'full',
#      u'isDefault': u'true',
#      u'medium': u'video',
#      u'type': u'application/x-shockwave-flash',
#      u'url': u'https://www.youtube.com/v/knUMjsGaL4s?version=3&f=user_uploads&app=youtube_gdata',
#      u'yt$format': 5},
#     {u'duration': 130,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r5---sn-o097zuee.c.youtube.com/CigLENy73wIaHwmLL5rBjgx1khMYDSANFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 1},
#     {u'duration': 130,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r5---sn-o097zuee.c.youtube.com/CigLENy73wIaHwmLL5rBjgx1khMYESARFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 6}],
#    u'media$description': {u'$t': u'\u8b1b\u984c\uff1aTITLE\n\u8b1b\u8005\uff1aSPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]',
#     u'type': u'plain'},
#    u'media$keywords': {},
#    u'media$player': [{u'url': u'https://www.youtube.com/watch?v=knUMjsGaL4s&feature=youtube_gdata_player'}],
#    u'media$thumbnail': [{u'height': 360,
#      u'time': u'00:01:05',
#      u'url': u'https://i.ytimg.com/vi/knUMjsGaL4s/0.jpg',
#      u'width': 480},
#     {u'height': 90,
#      u'time': u'00:00:32.500',
#      u'url': u'https://i.ytimg.com/vi/knUMjsGaL4s/1.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:01:05',
#      u'url': u'https://i.ytimg.com/vi/knUMjsGaL4s/2.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:01:37.500',
#      u'url': u'https://i.ytimg.com/vi/knUMjsGaL4s/3.jpg',
#      u'width': 120}],
#    u'media$title': {u'$t': u'20140721 R Basic part 9 by QMal (MLDM Monday)',
#     u'type': u'plain'},
#    u'yt$duration': {u'seconds': u'130'}},
#   u'published': {u'$t': u'2014-08-05T16:55:47.000Z'},
#   u'title': {u'$t': u'20140721 R Basic part 9 by QMal (MLDM Monday)',
#    u'type': u'text'},
#   u'updated': {u'$t': u'2014-08-05T16:55:47.000Z'},
#   u'yt$hd': {},
#   u'yt$statistics': {u'favoriteCount': u'0', u'viewCount': u'17'}},
#  {u'author': [{u'name': {u'$t': u'TW use-R'},
#     u'uri': {u'$t': u'https://gdata.youtube.com/feeds/users/TWuseRGroup'}}],
#   u'category': [{u'scheme': u'http://schemas.google.com/g/2005#kind',
#     u'term': u'http://gdata.youtube.com/schemas/2007#video'},
#    {u'label': u'Science & Technology',
#     u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat',
#     u'term': u'Tech'}],
#   u'content': {u'$t': u'<div style="color: #000000;font-family: Arial, Helvetica, sans-serif;     font-size:12px; font-size: 12px; width: 555px;">\n<table cellspacing="0" cellpadding="0" border="0"><tbody><tr><td width="140" valign="top" rowspan="2"><div style="border: 1px solid #999999; margin: 0px 10px 5px 0px;"><a href="https://www.youtube.com/watch?v=vGIEaXda478&amp;feature=youtube_gdata"><img alt="" src="https://i.ytimg.com/vi/vGIEaXda478/0.jpg"></a></div></td>\n<td width="256" valign="top"><div style="font-size: 12px; font-weight: bold;"><a style="font-size: 15px; font-weight: bold;                  font-decoration: none;" href="https://www.youtube.com/watch?v=vGIEaXda478&amp;feature=youtube_gdata">20140721 R Basic part 4 by QMal (MLDM Monday)</a>\n<br></div>\n<div style="font-size: 12px; margin: 3px 0px;"><span>&#35611;&#38988;&#65306;TITLE\n&#35611;&#32773;&#65306;SPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]</span></div></td>\n<td style="font-size: 11px; line-height: 1.4em; padding-left: 20px;             padding-top: 1px;" width="146" valign="top"><div><span style="color: #666666; font-size: 11px;">From:</span>\n<a href="https://www.youtube.com/channel/UCBBwy_xvVsM5iLB5dJZDqog">TW use-R</a></div>\n<div><span style="color: #666666; font-size: 11px;">Views:</span>\n32</div>\n<div style="white-space: nowrap;text-align: left"><img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"> <img style="border: 0px none; margin: 0px; padding: 0px;                    vertical-align: middle; font-size: 11px;" align="top" alt="" src="https://gdata.youtube.com/static/images/icn_star_empty_11x11.gif"></div>\n<div style="font-size: 11px;">0\n<span style="color: #666666; font-size: 11px;">ratings</span></div></td></tr>\n<tr><td><span style="color: #666666; font-size: 11px;">Time:</span>\n<span style="color: #000000; font-size: 11px; font-weight: bold;">02:19</span></td>\n<td style="font-size: 11px; padding-left: 20px;"><span style="color: #666666; font-size: 11px;">More in</span>\n<a href="https://www.youtube.com/videos?c=28">Science &amp; Technology</a></td></tr></tbody></table></div>',
#    u'type': u'html'},
#   u'gd$comments': {u'gd$feedLink': {u'countHint': 0,
#     u'href': u'https://gdata.youtube.com/feeds/videos/vGIEaXda478/comments',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#comments'}},
#   u'georss$where': {u'gml$Point': {u'gml$pos': {u'$t': u'25.0300998688 121.527618408'}}},
#   u'id': {u'$t': u'http://gdata.youtube.com/feeds/videos/vGIEaXda478'},
#   u'link': [{u'href': u'https://www.youtube.com/watch?v=vGIEaXda478&feature=youtube_gdata',
#     u'rel': u'alternate',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/videos/vGIEaXda478/related',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#video.related',
#     u'type': u'application/atom+xml'},
#    {u'href': u'https://m.youtube.com/details?v=vGIEaXda478',
#     u'rel': u'http://gdata.youtube.com/schemas/2007#mobile',
#     u'type': u'text/html'},
#    {u'href': u'https://gdata.youtube.com/feeds/users/TWuseRGroup/uploads/vGIEaXda478',
#     u'rel': u'self',
#     u'type': u'application/atom+xml'}],
#   u'media$group': {u'media$category': [{u'$t': u'Tech',
#      u'label': u'Science & Technology',
#      u'scheme': u'http://gdata.youtube.com/schemas/2007/categories.cat'}],
#    u'media$content': [{u'duration': 139,
#      u'expression': u'full',
#      u'isDefault': u'true',
#      u'medium': u'video',
#      u'type': u'application/x-shockwave-flash',
#      u'url': u'https://www.youtube.com/v/vGIEaXda478?version=3&f=user_uploads&app=youtube_gdata',
#      u'yt$format': 5},
#     {u'duration': 139,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r6---sn-o097zuel.c.youtube.com/CigLENy73wIaHwm_41p3aQRivBMYDSANFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 1},
#     {u'duration': 139,
#      u'expression': u'full',
#      u'medium': u'video',
#      u'type': u'video/3gpp',
#      u'url': u'rtsp://r6---sn-o097zuel.c.youtube.com/CigLENy73wIaHwm_41p3aQRivBMYESARFEgGUgx1c2VyX3VwbG9hZHMM/0/0/0/video.3gp',
#      u'yt$format': 6}],
#    u'media$description': {u'$t': u'\u8b1b\u984c\uff1aTITLE\n\u8b1b\u8005\uff1aSPEAKER\n\nAbstract\n\n[Abstract or Description]\n\nAbout the Speaker\n\n[About the Speaker]',
#     u'type': u'plain'},
#    u'media$keywords': {},
#    u'media$player': [{u'url': u'https://www.youtube.com/watch?v=vGIEaXda478&feature=youtube_gdata_player'}],
#    u'media$thumbnail': [{u'height': 360,
#      u'time': u'00:01:09.500',
#      u'url': u'https://i.ytimg.com/vi/vGIEaXda478/0.jpg',
#      u'width': 480},
#     {u'height': 90,
#      u'time': u'00:00:34.750',
#      u'url': u'https://i.ytimg.com/vi/vGIEaXda478/1.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:01:09.500',
#      u'url': u'https://i.ytimg.com/vi/vGIEaXda478/2.jpg',
#      u'width': 120},
#     {u'height': 90,
#      u'time': u'00:01:44.250',
#      u'url': u'https://i.ytimg.com/vi/vGIEaXda478/3.jpg',
#      u'width': 120}],
#    u'media$title': {u'$t': u'20140721 R Basic part 4 by QMal (MLDM Monday)',
#     u'type': u'plain'},
#    u'yt$duration': {u'seconds': u'139'}},
#   u'published': {u'$t': u'2014-08-05T16:23:42.000Z'},
#   u'title': {u'$t': u'20140721 R Basic part 4 by QMal (MLDM Monday)',
#    u'type': u'text'},
#   u'updated': {u'$t': u'2014-08-05T16:23:42.000Z'},
#   u'yt$hd': {},
#   u'yt$statistics': {u'favoriteCount': u'0', u'viewCount': u'32'}}]
