# %%
from pycrawlers.examples.yhstock.crawlers import *
# Out:
# /home/c3h3/.pyenv/versions/py27/lib/python2.7/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /home/c3h3/.pyenv/versions/2.7.7/lib/python2.7/argparse.pyc, but /home/c3h3/.pyenv/versions/py27/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /home/c3h3/.pyenv/versions/py27/lib/python2.7/site-packages/pandas-0.14.1_150_g1ffaab5-py2.7-linux-x86_64.egg/pandas/io/html.py:835: FutureWarning: infer_types has no effect since 0.15
#   warnings.warn("infer_types has no effect since 0.15", FutureWarning)

# %%
def get_stock_major_data(stock_id):

    res = requests.get("https://tw.stock.yahoo.com/d/s/major_{stock_id}.html".format(stock_id=stock_id))
    S = PyQuery(res.text)
    
    date_list = map(int,re.findall("[0-9]+",S("td.tt").filter(lambda i,e:len(PyQuery(e).text().split("/"))>1).text()))
    date_list[0] = date_list[0]+1911
    date = "-".join(map(str,date_list))
    
    data_table = pd.read_html(S("table").filter(lambda i,e:len(PyQuery(e)("td.ttt")) == 128).outerHtml())[0]
    
    pre_df = np.r_[ data_table.values[1:,0:4], data_table.values[1:,4:]]
    df = pd.DataFrame(pre_df)
    df.columns = ["trader","buy","sell","net"]
    df["stockId"] = df["trader"].map(lambda xx: stock_id)
    df["dateString"] = df["trader"].map(lambda xx: date)
    df = df[["dateString","stockId","trader","buy","sell","net"]]

    
    df["buy"] = df["buy"].fillna(0).map(lambda xx:int(xx))
    df["sell"] = df["sell"].fillna(0).map(lambda xx:int(xx))
    df["net"] = df["net"].fillna(0).map(lambda xx:int(xx))
    
    return {"stockId":stock_id,"date":date,"data":df}

# %%
one_stock_data = get_stock_major_data("3008")

# %%
one_stock_data["data"]
# Out:
#     dateString stockId trader  buy  sell  net
# 0   2014-10-17    3008   瑞士信貸  238    31  207
# 1   2014-10-17    3008   美商高盛  229    32  197
# 2   2014-10-17    3008   元大寶來  364   250  114
# 3   2014-10-17    3008   富邦證券  235   156   79
# 4   2014-10-17    3008   玉山證券   65    28   37
# 5   2014-10-17    3008   新光證券   38     9   29
# 6   2014-10-17    3008  永豐金證券  126    98   28
# 7   2014-10-17    3008   台灣企銀   30     6   24
# 8   2014-10-17    3008   中信銀證   24     3   21
# 9   2014-10-17    3008   國泰證券   39    20   19
# 10  2014-10-17    3008   凱基證券  271   255   16
# 11  2014-10-17    3008   國票證券   30    17   13
# 12  2014-10-17    3008  港商麥格里   29    17   12
# 13  2014-10-17    3008   港商野村   11     0   11
# 14  2014-10-17    3008     臺銀   14     6    8
# 15  2014-10-17    3008    第一金   33   168 -135
# 16  2014-10-17    3008  新加坡商瑞    7   111 -104
# 17  2014-10-17    3008     美林    0    95  -95
# 18  2014-10-17    3008   兆豐證券   64   155  -91
# 19  2014-10-17    3008     統一  124   211  -87
# 20  2014-10-17    3008     元富   70   147  -77
# 21  2014-10-17    3008  港商德意志    0    71  -71
# 22  2014-10-17    3008  台灣摩根士   27    62  -35
# 23  2014-10-17    3008   群益金鼎  100   122  -22
# 24  2014-10-17    3008   港商聯昌    4    22  -18
# 25  2014-10-17    3008  港商法國興    0    15  -15
# 26  2014-10-17    3008    新百王    0     8   -8
# 27  2014-10-17    3008     亞東    7    12   -5
# 28  2014-10-17    3008   大眾證券   17    20   -3
# 29  2014-10-17    3008   摩根大通   17    19   -2

# %%
one_stock_data["data"].to_dict(outtype="record")
# Out:
# [{'buy': 238,
#   'dateString': '2014-10-17',
#   'net': 207,
#   'sell': 31,
#   'stockId': '3008',
#   'trader': u'\u745e\u58eb\u4fe1\u8cb8'},
#  {'buy': 229,
#   'dateString': '2014-10-17',
#   'net': 197,
#   'sell': 32,
#   'stockId': '3008',
#   'trader': u'\u7f8e\u5546\u9ad8\u76db'},
#  {'buy': 364,
#   'dateString': '2014-10-17',
#   'net': 114,
#   'sell': 250,
#   'stockId': '3008',
#   'trader': u'\u5143\u5927\u5bf6\u4f86'},
#  {'buy': 235,
#   'dateString': '2014-10-17',
#   'net': 79,
#   'sell': 156,
#   'stockId': '3008',
#   'trader': u'\u5bcc\u90a6\u8b49\u5238'},
#  {'buy': 65,
#   'dateString': '2014-10-17',
#   'net': 37,
#   'sell': 28,
#   'stockId': '3008',
#   'trader': u'\u7389\u5c71\u8b49\u5238'},
#  {'buy': 38,
#   'dateString': '2014-10-17',
#   'net': 29,
#   'sell': 9,
#   'stockId': '3008',
#   'trader': u'\u65b0\u5149\u8b49\u5238'},
#  {'buy': 126,
#   'dateString': '2014-10-17',
#   'net': 28,
#   'sell': 98,
#   'stockId': '3008',
#   'trader': u'\u6c38\u8c50\u91d1\u8b49\u5238'},
#  {'buy': 30,
#   'dateString': '2014-10-17',
#   'net': 24,
#   'sell': 6,
#   'stockId': '3008',
#   'trader': u'\u53f0\u7063\u4f01\u9280'},
#  {'buy': 24,
#   'dateString': '2014-10-17',
#   'net': 21,
#   'sell': 3,
#   'stockId': '3008',
#   'trader': u'\u4e2d\u4fe1\u9280\u8b49'},
#  {'buy': 39,
#   'dateString': '2014-10-17',
#   'net': 19,
#   'sell': 20,
#   'stockId': '3008',
#   'trader': u'\u570b\u6cf0\u8b49\u5238'},
#  {'buy': 271,
#   'dateString': '2014-10-17',
#   'net': 16,
#   'sell': 255,
#   'stockId': '3008',
#   'trader': u'\u51f1\u57fa\u8b49\u5238'},
#  {'buy': 30,
#   'dateString': '2014-10-17',
#   'net': 13,
#   'sell': 17,
#   'stockId': '3008',
#   'trader': u'\u570b\u7968\u8b49\u5238'},
#  {'buy': 29,
#   'dateString': '2014-10-17',
#   'net': 12,
#   'sell': 17,
#   'stockId': '3008',
#   'trader': u'\u6e2f\u5546\u9ea5\u683c\u91cc'},
#  {'buy': 11,
#   'dateString': '2014-10-17',
#   'net': 11,
#   'sell': 0,
#   'stockId': '3008',
#   'trader': u'\u6e2f\u5546\u91ce\u6751'},
#  {'buy': 14,
#   'dateString': '2014-10-17',
#   'net': 8,
#   'sell': 6,
#   'stockId': '3008',
#   'trader': u'\u81fa\u9280'},
#  {'buy': 33,
#   'dateString': '2014-10-17',
#   'net': -135,
#   'sell': 168,
#   'stockId': '3008',
#   'trader': u'\u7b2c\u4e00\u91d1'},
#  {'buy': 7,
#   'dateString': '2014-10-17',
#   'net': -104,
#   'sell': 111,
#   'stockId': '3008',
#   'trader': u'\u65b0\u52a0\u5761\u5546\u745e'},
#  {'buy': 0,
#   'dateString': '2014-10-17',
#   'net': -95,
#   'sell': 95,
#   'stockId': '3008',
#   'trader': u'\u7f8e\u6797'},
#  {'buy': 64,
#   'dateString': '2014-10-17',
#   'net': -91,
#   'sell': 155,
#   'stockId': '3008',
#   'trader': u'\u5146\u8c50\u8b49\u5238'},
#  {'buy': 124,
#   'dateString': '2014-10-17',
#   'net': -87,
#   'sell': 211,
#   'stockId': '3008',
#   'trader': u'\u7d71\u4e00'},
#  {'buy': 70,
#   'dateString': '2014-10-17',
#   'net': -77,
#   'sell': 147,
#   'stockId': '3008',
#   'trader': u'\u5143\u5bcc'},
#  {'buy': 0,
#   'dateString': '2014-10-17',
#   'net': -71,
#   'sell': 71,
#   'stockId': '3008',
#   'trader': u'\u6e2f\u5546\u5fb7\u610f\u5fd7'},
#  {'buy': 27,
#   'dateString': '2014-10-17',
#   'net': -35,
#   'sell': 62,
#   'stockId': '3008',
#   'trader': u'\u53f0\u7063\u6469\u6839\u58eb'},
#  {'buy': 100,
#   'dateString': '2014-10-17',
#   'net': -22,
#   'sell': 122,
#   'stockId': '3008',
#   'trader': u'\u7fa4\u76ca\u91d1\u9f0e'},
#  {'buy': 4,
#   'dateString': '2014-10-17',
#   'net': -18,
#   'sell': 22,
#   'stockId': '3008',
#   'trader': u'\u6e2f\u5546\u806f\u660c'},
#  {'buy': 0,
#   'dateString': '2014-10-17',
#   'net': -15,
#   'sell': 15,
#   'stockId': '3008',
#   'trader': u'\u6e2f\u5546\u6cd5\u570b\u8208'},
#  {'buy': 0,
#   'dateString': '2014-10-17',
#   'net': -8,
#   'sell': 8,
#   'stockId': '3008',
#   'trader': u'\u65b0\u767e\u738b'},
#  {'buy': 7,
#   'dateString': '2014-10-17',
#   'net': -5,
#   'sell': 12,
#   'stockId': '3008',
#   'trader': u'\u4e9e\u6771'},
#  {'buy': 17,
#   'dateString': '2014-10-17',
#   'net': -3,
#   'sell': 20,
#   'stockId': '3008',
#   'trader': u'\u5927\u773e\u8b49\u5238'},
#  {'buy': 17,
#   'dateString': '2014-10-17',
#   'net': -2,
#   'sell': 19,
#   'stockId': '3008',
#   'trader': u'\u6469\u6839\u5927\u901a'}]

# %%
one_stock_data
# Out:
# {'data':     dateString stockId trader  buy  sell  net
#  0   2014-10-17    3008   瑞士信貸  238    31  207
#  1   2014-10-17    3008   美商高盛  229    32  197
#  2   2014-10-17    3008   元大寶來  364   250  114
#  3   2014-10-17    3008   富邦證券  235   156   79
#  4   2014-10-17    3008   玉山證券   65    28   37
#  5   2014-10-17    3008   新光證券   38     9   29
#  6   2014-10-17    3008  永豐金證券  126    98   28
#  7   2014-10-17    3008   台灣企銀   30     6   24
#  8   2014-10-17    3008   中信銀證   24     3   21
#  9   2014-10-17    3008   國泰證券   39    20   19
#  10  2014-10-17    3008   凱基證券  271   255   16
#  11  2014-10-17    3008   國票證券   30    17   13
#  12  2014-10-17    3008  港商麥格里   29    17   12
#  13  2014-10-17    3008   港商野村   11     0   11
#  14  2014-10-17    3008     臺銀   14     6    8
#  15  2014-10-17    3008    第一金   33   168 -135
#  16  2014-10-17    3008  新加坡商瑞    7   111 -104
#  17  2014-10-17    3008     美林    0    95  -95
#  18  2014-10-17    3008   兆豐證券   64   155  -91
#  19  2014-10-17    3008     統一  124   211  -87
#  20  2014-10-17    3008     元富   70   147  -77
#  21  2014-10-17    3008  港商德意志    0    71  -71
#  22  2014-10-17    3008  台灣摩根士   27    62  -35
#  23  2014-10-17    3008   群益金鼎  100   122  -22
#  24  2014-10-17    3008   港商聯昌    4    22  -18
#  25  2014-10-17    3008  港商法國興    0    15  -15
#  26  2014-10-17    3008    新百王    0     8   -8
#  27  2014-10-17    3008     亞東    7    12   -5
#  28  2014-10-17    3008   大眾證券   17    20   -3
#  29  2014-10-17    3008   摩根大通   17    19   -2,
#  'date': '2014-10-17',
#  'stockId': '3008'}

# %%
one_stock_data["date"]
# Out:
# '2014-10-16'

# %%
one_stock_data["data"].to_dict(outtype="record")
# Out:
# [{'buy': '125',
#   'dateString': '2014-10-16',
#   'net': '+124',
#   'sell': '1',
#   'stockId': '3008',
#   'trader': u'\u6469\u6839\u5927\u901a'},
#  {'buy': '98',
#   'dateString': '2014-10-16',
#   'net': '+38',
#   'sell': '60',
#   'stockId': '3008',
#   'trader': u'\u7f8e\u6797'},
#  {'buy': '229',
#   'dateString': '2014-10-16',
#   'net': '+28',
#   'sell': '201',
#   'stockId': '3008',
#   'trader': u'\u51f1\u57fa\u8b49\u5238'},
#  {'buy': '25',
#   'dateString': '2014-10-16',
#   'net': '+12',
#   'sell': '13',
#   'stockId': '3008',
#   'trader': u'\u65b0\u52a0\u5761\u5546\u745e'},
#  {'buy': '35',
#   'dateString': '2014-10-16',
#   'net': '+12',
#   'sell': '23',
#   'stockId': '3008',
#   'trader': u'\u7389\u5c71\u8b49\u5238'},
#  {'buy': '10',
#   'dateString': '2014-10-16',
#   'net': '+10',
#   'sell': '0',
#   'stockId': '3008',
#   'trader': u'\u6e2f\u5546\u806f\u660c'},
#  {'buy': '16',
#   'dateString': '2014-10-16',
#   'net': '+8',
#   'sell': '8',
#   'stockId': '3008',
#   'trader': u'\u5927\u773e\u8b49\u5238'},
#  {'buy': '9',
#   'dateString': '2014-10-16',
#   'net': '+7',
#   'sell': '2',
#   'stockId': '3008',
#   'trader': u'\u5fb7\u4fe1\u8b49\u5238'},
#  {'buy': '156',
#   'dateString': '2014-10-16',
#   'net': '+5',
#   'sell': '151',
#   'stockId': '3008',
#   'trader': u'\u6e2f\u5546\u5fb7\u610f\u5fd7'},
#  {'buy': '7',
#   'dateString': '2014-10-16',
#   'net': '+5',
#   'sell': '2',
#   'stockId': '3008',
#   'trader': u'\u5317\u57ce\u8b49\u5238'},
#  {'buy': '4',
#   'dateString': '2014-10-16',
#   'net': '+4',
#   'sell': '0',
#   'stockId': '3008',
#   'trader': u'\u53f0\u7063\u6771\u65b9\u532f'},
#  {'buy': '10',
#   'dateString': '2014-10-16',
#   'net': '+3',
#   'sell': '7',
#   'stockId': '3008',
#   'trader': u'\u5927\u660c\u8b49\u5238'},
#  {'buy': '4',
#   'dateString': '2014-10-16',
#   'net': '+2',
#   'sell': '2',
#   'stockId': '3008',
#   'trader': u'\u946b\u8c50\u8b49\u5238'},
#  {'buy': '5',
#   'dateString': '2014-10-16',
#   'net': '+1',
#   'sell': '4',
#   'stockId': '3008',
#   'trader': u'\u5408\u5eab'},
#  {'buy': '1',
#   'dateString': '2014-10-16',
#   'net': '+1',
#   'sell': '0',
#   'stockId': '3008',
#   'trader': u'\u6c38\u5168\u8b49\u5238'},
#  {'buy': '29',
#   'dateString': '2014-10-16',
#   'net': '-47',
#   'sell': '76',
#   'stockId': '3008',
#   'trader': u'\u7fa4\u76ca\u91d1\u9f0e'},
#  {'buy': '98',
#   'dateString': '2014-10-16',
#   'net': '-45',
#   'sell': '143',
#   'stockId': '3008',
#   'trader': u'\u5bcc\u90a6\u8b49\u5238'},
#  {'buy': '3',
#   'dateString': '2014-10-16',
#   'net': '-38',
#   'sell': '41',
#   'stockId': '3008',
#   'trader': u'\u82b1\u65d7\u74b0\u7403'},
#  {'buy': '190',
#   'dateString': '2014-10-16',
#   'net': '-25',
#   'sell': '215',
#   'stockId': '3008',
#   'trader': u'\u5143\u5927\u5bf6\u4f86'},
#  {'buy': '5',
#   'dateString': '2014-10-16',
#   'net': '-19',
#   'sell': '24',
#   'stockId': '3008',
#   'trader': u'\u53f0\u65b0\u8b49\u5238'},
#  {'buy': '52',
#   'dateString': '2014-10-16',
#   'net': '-13',
#   'sell': '65',
#   'stockId': '3008',
#   'trader': u'\u5143\u5bcc'},
#  {'buy': '7',
#   'dateString': '2014-10-16',
#   'net': '-12',
#   'sell': '19',
#   'stockId': '3008',
#   'trader': u'\u4e2d\u4fe1\u9280\u8b49'},
#  {'buy': '12',
#   'dateString': '2014-10-16',
#   'net': '-11',
#   'sell': '23',
#   'stockId': '3008',
#   'trader': u'\u53f0\u7063\u6469\u6839\u58eb'},
#  {'buy': '25',
#   'dateString': '2014-10-16',
#   'net': '-11',
#   'sell': '36',
#   'stockId': '3008',
#   'trader': u'\u5b8f\u9060\u8b49\u5238'},
#  {'buy': '2',
#   'dateString': '2014-10-16',
#   'net': '-10',
#   'sell': '12',
#   'stockId': '3008',
#   'trader': u'\u571f\u9280'},
#  {'buy': '3',
#   'dateString': '2014-10-16',
#   'net': '-9',
#   'sell': '12',
#   'stockId': '3008',
#   'trader': u'\u53f0\u7063\u4f01\u9280'},
#  {'buy': '18',
#   'dateString': '2014-10-16',
#   'net': '-8',
#   'sell': '26',
#   'stockId': '3008',
#   'trader': u'\u7b2c\u4e00\u91d1'},
#  {'buy': '157',
#   'dateString': '2014-10-16',
#   'net': '-8',
#   'sell': '165',
#   'stockId': '3008',
#   'trader': u'\u6c38\u8c50\u91d1\u8b49\u5238'},
#  {'buy': '8',
#   'dateString': '2014-10-16',
#   'net': '-7',
#   'sell': '15',
#   'stockId': '3008',
#   'trader': u'\u81fa\u9280'},
#  {'buy': '1',
#   'dateString': '2014-10-16',
#   'net': '-7',
#   'sell': '8',
#   'stockId': '3008',
#   'trader': u'\u745e\u58eb\u4fe1\u8cb8'}]

# %%
df.to_dict?

# %%
one_stock_data["data"].todict

# %%
one_stock_data["data"].to_dict

# %%
from pymongo import MongoClient

# %%
mongo_cli = MongoClient()

# %%
import datetime

# %%
def update_all_stock_major_data(data_collection, error_collection):
    
    twse_ids = get_stockID_twse('sii').tolist()
    twotc_ids = get_stockID_twse('otc').tolist()
    
    stock_ids = twse_ids + twotc_ids
    #stock_ids = stock_ids[:10]
    
    while len(stock_ids) > 0:
        print "~~~~~~~~~~~~~~~~~~~~~~~~"
        print "len(stock_ids) = ",len(stock_ids)
        one_stock_id = stock_ids.pop()
        
        try:
            one_stock_data = get_stock_major_data(one_stock_id)
            one_stock_data_in_db = data_collection.find({"stockId":one_stock_data["stockId"],"dateString":one_stock_data["dateString"]}).count()>0
            if not one_stock_data_in_db:
                data_collection.insert(one_stock_data["data"].to_dict(outtype="record"))
                print "%s -- SUCCESS: insert into db " % one_stock_id
            else:
                print "%s -- SUCCESS: already in db " % one_stock_id
                
            
            
        except Exception as e:
            print "%s -- ERROR" % one_stock_id
            print e
            print traceback.format_exc()
            #print e.__dict__
            #print e.message
            #print pickle.dumps(e.request)
            error_collection.insert({"stockId":one_stock_id,
                                    "message":e.message,
                                    "traceback":traceback.format_exc(),
                                    "time":datetime.datetime.now()})
