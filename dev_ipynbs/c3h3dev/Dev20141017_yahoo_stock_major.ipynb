# %%
import requests
import pandas as pd 
from pyquery import PyQuery
import re
import numpy as np
from pycrawlers.examples.twse.crawlers import get_stockID_twse
# Out:
# /home/c3h3/.pyenv/versions/py27/lib/python2.7/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /home/c3h3/.pyenv/versions/2.7.7/lib/python2.7/argparse.pyc, but /home/c3h3/.pyenv/versions/py27/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
stock_id = "8077"

# %%
res = requests.get("https://tw.stock.yahoo.com/d/s/major_{stock_id}.html".format(stock_id=stock_id))

# %%
S = PyQuery(res.text)

# %%
date_list = map(int,re.findall("[0-9]+",S("td.tt").filter(lambda i,e:len(PyQuery(e).text().split("/"))>1).text()))

# %%
date_list[0] = date_list[0]+1911
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-bac084b0a788> in <module>()
# ----> 1 date_list[0] = date_list[0]+1911
#
# IndexError: list index out of range

# %%
date = "-".join(map(str,date_list))

# %%
S("table").map(lambda i,e:len(PyQuery(e)("td.ttt")))
# Out:
# [0, 0, 0, 0, 0, 0, 0, 129, 1, 128, 0]

# %%
df = pd.read_html(S("table").filter(lambda i,e:len(PyQuery(e)("td.ttt")) == 128).outerHtml())[0]

# %%
data_table = df
pre_df = np.r_[ data_table.values[1:,0:4], data_table.values[1:,4:]]

# %%
df = pd.DataFrame(pre_df)
df.columns = ["name","buy","sell","net"]
df["stockId"] = df["name"].map(lambda xx: stock_id)
df["dateString"] = df["name"].map(lambda xx: date)
df = df[["dateString","stockId","name","buy","sell","net"]]
df
# Out:
# Empty DataFrame
# Columns: [dateString, stockId, name, buy, sell, net]
# Index: []

# %%
def get_stock_major_data(stock_id):

    res = requests.get("https://tw.stock.yahoo.com/d/s/major_{stock_id}.html".format(stock_id=stock_id))
    S = PyQuery(res.text)
    
    date_list = map(int,re.findall("[0-9]+",S("td.tt").filter(lambda i,e:len(PyQuery(e).text().split("/"))>1).text()))
    date_list[0] = date_list[0]+1911
    date = "-".join(map(str,date_list))
    
    data_table = pd.read_html(S("table").filter(lambda i,e:len(PyQuery(e)("td.ttt")) == 128).outerHtml())[0]
    
    pre_df = np.r_[ data_table.values[1:,0:4], data_table.values[1:,4:]]
    df = pd.DataFrame(pre_df)
    df.columns = ["trader","buy","sell","net"]
    df["stockId"] = df["trader"].map(lambda xx: stock_id)
    df["dateString"] = df["trader"].map(lambda xx: date)
    df = df[["dateString","stockId","trader","buy","sell","net"]]
    
    return df

# %%
get_stock_major_data("3008")
# Out:
#     dateString stockId trader  buy sell   net
# 0   2014-10-16    3008   摩根大通  125    1  +124
# 1   2014-10-16    3008     美林   98   60   +38
# 2   2014-10-16    3008   凱基證券  229  201   +28
# 3   2014-10-16    3008  新加坡商瑞   25   13   +12
# 4   2014-10-16    3008   玉山證券   35   23   +12
# 5   2014-10-16    3008   港商聯昌   10    0   +10
# 6   2014-10-16    3008   大眾證券   16    8    +8
# 7   2014-10-16    3008   德信證券    9    2    +7
# 8   2014-10-16    3008   北城證券    7    2    +5
# 9   2014-10-16    3008  港商德意志  156  151    +5
# 10  2014-10-16    3008  台灣東方匯    4    0    +4
# 11  2014-10-16    3008   大昌證券   10    7    +3
# 12  2014-10-16    3008   鑫豐證券    4    2    +2
# 13  2014-10-16    3008     日茂    1    0    +1
# 14  2014-10-16    3008     合庫    5    4    +1
# 15  2014-10-16    3008   群益金鼎   29   76   -47
# 16  2014-10-16    3008   富邦證券   98  143   -45
# 17  2014-10-16    3008   花旗環球    3   41   -38
# 18  2014-10-16    3008   元大寶來  190  215   -25
# 19  2014-10-16    3008   台新證券    5   24   -19
# 20  2014-10-16    3008     元富   52   65   -13
# 21  2014-10-16    3008   中信銀證    7   19   -12
# 22  2014-10-16    3008   宏遠證券   25   36   -11
# 23  2014-10-16    3008  台灣摩根士   12   23   -11
# 24  2014-10-16    3008     土銀    2   12   -10
# 25  2014-10-16    3008   台灣企銀    3   12    -9
# 26  2014-10-16    3008  永豐金證券  157  165    -8
# 27  2014-10-16    3008    第一金   18   26    -8
# 28  2014-10-16    3008   國泰證券   27   34    -7
# 29  2014-10-16    3008     臺銀    8   15    -7

# %%
import cPickle as pickle
import traceback

# %%
def get_all_stock_major_data():
    all_data_df_list = []
    error_stock_ids = []
    
    twse_ids = get_stockID_twse('sii').tolist()
    twotc_ids = get_stockID_twse('otc').tolist()
    
    stock_ids = twse_ids + twotc_ids
    #stock_ids = stock_ids[:10]
    
    while len(stock_ids) > 0:
        print "len(stock_ids) = ",len(stock_ids)
        one_stock_id = stock_ids.pop()
        
        try:
            one_stock_df = get_stock_major_data(one_stock_id)
            all_data_df_list.append(one_stock_df)
            print "%s -- SUCCESS" % one_stock_id
        except Exception as e:
            print "%s -- ERROR" % one_stock_id
            print e
            print traceback.format_exc()
            #print e.__dict__
            #print e.message
            #print pickle.dumps(e.request)
            
            error_stock_ids.append({"stockId":one_stock_id,
                                    "message":e.message,
                                    "traceback":traceback.format_exc()})
    
    return {"data":pd.concat(all_data_df_list), "error":error_stock_ids}

# %%
# %time test = get_all_stock_major_data()
# Out:
# len(stock_ids) =  1552
# 9962 -- SUCCESS
# len(stock_ids) =  1551
# 9960 -- SUCCESS
# len(stock_ids) =  1550
# 9951 -- SUCCESS
# len(stock_ids) =  1549
# 9950 -- SUCCESS
# len(stock_ids) =  1548
# 9949 -- SUCCESS
# len(stock_ids) =  1547
# 911613 -- ERROR

# %%
t = range(123)

# %%
t.pop()
# Out:
# 117

# %%
test = map(get_stock_major_data,twse_ids[:10])

# %%
pd.concat(test)
# Out:
#     dateString stockId trader  buy  sell   net
# 0   2014-10-16    1101   港商野村  771     0  +771
# 1   2014-10-16    1101   港商聯昌  400     0  +400
# 2   2014-10-16    1101  台灣巴克萊  352     0  +352
# 3   2014-10-16    1101   摩根大通  379    66  +313
# 4   2014-10-16    1101   國票證券  218    19  +199
# 5   2014-10-16    1101     亞東  616   516  +100
# 6   2014-10-16    1101   大慶證券   97     7   +90
# 7   2014-10-16    1101   華南永昌   59    19   +40
