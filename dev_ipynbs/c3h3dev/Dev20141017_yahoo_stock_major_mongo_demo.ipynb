# %%
from pycrawlers.examples.yhstock.crawlers import *
# Out:
# /home/c3h3/.pyenv/versions/py27/lib/python2.7/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /home/c3h3/.pyenv/versions/2.7.7/lib/python2.7/argparse.pyc, but /home/c3h3/.pyenv/versions/py27/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream
# /home/c3h3/.pyenv/versions/py27/lib/python2.7/site-packages/pandas-0.14.1_150_g1ffaab5-py2.7-linux-x86_64.egg/pandas/io/html.py:835: FutureWarning: infer_types has no effect since 0.15
#   warnings.warn("infer_types has no effect since 0.15", FutureWarning)

# %%
test = get_stock_major_data("2330")

# %%
test.to_dict(outtype="record")
# Out:
# [{'buy': '4504',
#   'dateString': '2014-10-16',
#   'net': '+2544',
#   'sell': '1960',
#   'stockId': '2330',
#   'trader': u'\u53f0\u7063\u6469\u6839\u58eb'},
#  {'buy': '2735',
#   'dateString': '2014-10-16',
#   'net': '+2149',
#   'sell': '586',
#   'stockId': '2330',
#   'trader': u'\u6cd5\u9280\u5df4\u9ece'},
#  {'buy': '3202',
#   'dateString': '2014-10-16',
#   'net': '+1810',
#   'sell': '1392',
#   'stockId': '2330',
#   'trader': u'\u6e2f\u5546\u9ea5\u683c\u91cc'},
#  {'buy': '1752',
#   'dateString': '2014-10-16',
#   'net': '+1709',
#   'sell': '43',
#   'stockId': '2330',
#   'trader': u'\u53f0\u7063\u5df4\u514b\u840a'},
#  {'buy': '2365',
#   'dateString': '2014-10-16',
#   'net': '+1647',
#   'sell': '718',
#   'stockId': '2330',
#   'trader': u'\u7f8e\u5546\u9ad8\u76db'},
#  {'buy': '1833',
#   'dateString': '2014-10-16',
#   'net': '+1534',
#   'sell': '299',
#   'stockId': '2330',
#   'trader': u'\u53f0\u7063\u6771\u65b9\u532f'},
#  {'buy': '1789',
# ...

# %%
from pymongo import MongoClient

# %%
mongo_cli = MongoClient()

# %%
#update_all_stock_major_data(mongo_cli.yhstock.major,mongo_cli.yhstock.majorError)

# %%
mongo_cli.yhstock.major.insert(test.to_dict(outtype="record"))
# Out:
# [ObjectId('5440d1e374798d3290ec43bd'),
#  ObjectId('5440d1e374798d3290ec43be'),
#  ObjectId('5440d1e374798d3290ec43bf'),
#  ObjectId('5440d1e374798d3290ec43c0'),
#  ObjectId('5440d1e374798d3290ec43c1'),
#  ObjectId('5440d1e374798d3290ec43c2'),
#  ObjectId('5440d1e374798d3290ec43c3'),
#  ObjectId('5440d1e374798d3290ec43c4'),
#  ObjectId('5440d1e374798d3290ec43c5'),
#  ObjectId('5440d1e374798d3290ec43c6'),
#  ObjectId('5440d1e374798d3290ec43c7'),
#  ObjectId('5440d1e374798d3290ec43c8'),
#  ObjectId('5440d1e374798d3290ec43c9'),
#  ObjectId('5440d1e374798d3290ec43ca'),
#  ObjectId('5440d1e374798d3290ec43cb'),
#  ObjectId('5440d1e374798d3290ec43cc'),
#  ObjectId('5440d1e374798d3290ec43cd'),
#  ObjectId('5440d1e374798d3290ec43ce'),
#  ObjectId('5440d1e374798d3290ec43cf'),
#  ObjectId('5440d1e374798d3290ec43d0'),
#  ObjectId('5440d1e374798d3290ec43d1'),
#  ObjectId('5440d1e374798d3290ec43d2'),
#  ObjectId('5440d1e374798d3290ec43d3'),
#  ObjectId('5440d1e374798d3290ec43d4'),
# ...
