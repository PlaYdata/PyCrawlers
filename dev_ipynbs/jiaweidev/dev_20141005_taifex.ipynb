# %%
from pandas.io.parsers import read_csv
from pandas import io
import requests

# %%
r = requests.get('http://www.taifex.com.tw/eng/eng7/log2data/201408old.txt')

read_csv(io.parsers.StringIO(r.text), header=None, sep='\t+')
# Out:
# /home/dboyliao/.pyenv/versions/anaconda-2.0.1/lib/python2.7/site-packages/pandas/io/parsers.py:615: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   ParserWarning)
#            0         1      2
# 0   20140801  13300000  10.85
# 1   20140804  13300000  10.80
# 2   20140805  13300000  12.31
# 3   20140806  13300100  11.92
# 4   20140807  13300100  11.21
# 5   20140808  13300000  11.33
# 6   20140811  13300000  11.58
# 7   20140812  13300000  11.28
# 8   20140813  13300000  11.07
# 9   20140814  13300000  10.90
# 10  20140815  13300000  10.73
# 11  20140818  13300000  11.67
# 12  20140819  13300000  11.25
# 13  20140820  13300000  10.96
# 14  20140821  13300000  10.75
# 15  20140822  13300100   9.95
# 16  20140825  13300000  10.52
# 17  20140826  13300000  10.59
# 18  20140827  13300000  10.09
# 19  20140828  13300000  10.19
# 20  20140829  13300000  10.19
